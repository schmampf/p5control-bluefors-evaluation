# %%
path = 'D:/Documents/coding/BlueForsLog'

from os import listdir
import numpy as np

dates = listdir(path)

t_p = np.array([], dtype='datetime64[s]')
p1 = np.array([], dtype='f8')
p2 = np.array([], dtype='f8')
p3 = np.array([], dtype='f8')
p4 = np.array([], dtype='f8')
p5 = np.array([], dtype='f8')
p6 = np.array([], dtype='f8')

t_T1 = np.array([], dtype='datetime64[s]')
T1 = np.array([], dtype='f8')
t_T2 = np.array([], dtype='datetime64[s]')
T2 = np.array([], dtype='f8')
t_T3 = np.array([], dtype='datetime64[s]')
T3 = np.array([], dtype='f8')
t_T5 = np.array([], dtype='datetime64[s]')
T5 = np.array([], dtype='f8')
t_T7 = np.array([], dtype='datetime64[s]')
T7 = np.array([], dtype='f8')
t_T8 = np.array([], dtype='datetime64[s]')
T8 = np.array([], dtype='f8')

for date in dates:
    # p
    try:
        a = np.genfromtxt(f"{path}/{date}/maxigauge {date}.log", delimiter=',',dtype= ('str'))

        t = np.empty(np.shape(a[:, 1]), dtype='S19') # S19 means string with 19 characters
        t.fill('20'+a[0,0][6:8]+'-'+a[0,0][3:5]+'-'+a[0,0][0:2]+' ')
        t = np.array(np.char.add(t, np.array(a[:, 1], dtype='S19')), dtype='datetime64[s]')

        t_p = np.concatenate((t_p, t), dtype='datetime64[s]')
        p1 = np.concatenate((p1, np.array(a[:,  5], dtype='float64')))
        p2 = np.concatenate((p2, np.array(a[:, 11], dtype='float64')))
        p3 = np.concatenate((p3, np.array(a[:, 17], dtype='float64')))
        p4 = np.concatenate((p4, np.array(a[:, 23], dtype='float64')))
        p5 = np.concatenate((p5, np.array(a[:, 29], dtype='float64')))
        p6 = np.concatenate((p6, np.array(a[:, 35], dtype='float64')))
    except:
        pass
    # T1
    try:
        b = np.genfromtxt(f"{path}/{date}/CH1 T {date}.log", delimiter=',',dtype= ('str'))
        t = np.empty(np.shape(b[:, 1]), dtype='S19') # S19 means string with 19 characters
        t.fill('20'+b[0,0][6:8]+'-'+b[0,0][3:5]+'-'+b[0,0][0:2]+' ')
        t = np.array(np.char.add(t, np.array(b[:, 1], dtype='S19')), dtype='datetime64[s]')        
        t_T1 = np.concatenate((t_T1, t), dtype='datetime64[s]')
        T1 = np.concatenate((T1, np.array(b[:,  2], dtype='float64')))
    except:
        pass
    # T2
    try:
        b = np.genfromtxt(f"{path}/{date}/CH2 T {date}.log", delimiter=',',dtype= ('str'))
        t = np.empty(np.shape(b[:, 1]), dtype='S19') # S19 means string with 19 characters
        t.fill('20'+b[0,0][6:8]+'-'+b[0,0][3:5]+'-'+b[0,0][0:2]+' ')
        t = np.array(np.char.add(t, np.array(b[:, 1], dtype='S19')), dtype='datetime64[s]')        
        t_T2 = np.concatenate((t_T2, t), dtype='datetime64[s]')
        T2 = np.concatenate((T2, np.array(b[:,  2], dtype='float64')))
    except:
        pass
    # T3
    try:
        b = np.genfromtxt(f"{path}/{date}/CH3 T {date}.log", delimiter=',',dtype= ('str'))
        t = np.empty(np.shape(b[:, 1]), dtype='S19') # S19 means string with 19 characters
        t.fill('20'+b[0,0][6:8]+'-'+b[0,0][3:5]+'-'+b[0,0][0:2]+' ')
        t = np.array(np.char.add(t, np.array(b[:, 1], dtype='S19')), dtype='datetime64[s]')        
        t_T3 = np.concatenate((t_T3, t), dtype='datetime64[s]')
        T3 = np.concatenate((T3, np.array(b[:,  2], dtype='float64')))
    except:
        pass
    # T5
    try:
        b = np.genfromtxt(f"{path}/{date}/CH5 T {date}.log", delimiter=',',dtype= ('str'))
        t = np.empty(np.shape(b[:, 1]), dtype='S19') # S19 means string with 19 characters
        t.fill('20'+b[0,0][6:8]+'-'+b[0,0][3:5]+'-'+b[0,0][0:2]+' ')
        t = np.array(np.char.add(t, np.array(b[:, 1], dtype='S19')), dtype='datetime64[s]')        
        t_T5 = np.concatenate((t_T5, t), dtype='datetime64[s]')
        T5 = np.concatenate((T5, np.array(b[:,  2], dtype='float64')))
    except:
        pass
    # T7
    try:
        b = np.genfromtxt(f"{path}/{date}/CH7 T {date}.log", delimiter=',',dtype= ('str'))
        t = np.empty(np.shape(b[:, 1]), dtype='S19') # S19 means string with 19 characters
        t.fill('20'+b[0,0][6:8]+'-'+b[0,0][3:5]+'-'+b[0,0][0:2]+' ')
        t = np.array(np.char.add(t, np.array(b[:, 1], dtype='S19')), dtype='datetime64[s]')        
        t_T7 = np.concatenate((t_T7, t), dtype='datetime64[s]')
        T7 = np.concatenate((T7, np.array(b[:,  2], dtype='float64')))
    except:
        pass
    # T8
    try:
        b = np.genfromtxt(f"{path}/{date}/CH8 T {date}.log", delimiter=',',dtype= ('str'))
        t = np.empty(np.shape(b[:, 1]), dtype='S19') # S19 means string with 19 characters
        t.fill('20'+b[0,0][6:8]+'-'+b[0,0][3:5]+'-'+b[0,0][0:2]+' ')
        t = np.array(np.char.add(t, np.array(b[:, 1], dtype='S19')), dtype='datetime64[s]')        
        t_T8 = np.concatenate((t_T8, t), dtype='datetime64[s]')
        T8 = np.concatenate((T8, np.array(b[:,  2], dtype='float64')))
    except:
        pass

# %%
import matplotlib.pyplot as plt

# %matplotlib qt
# %matplotlib inline 

fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True)
ax1, ax2 = axes.flatten()
ax1.set_title('Temperatures and Pressures from BlueFors Logs')

ax1.plot(t_T1, T1, '.', label='T1 = 50K')
ax1.plot(t_T2, T2, '.', label='T2 = 4 K')
ax1.plot(t_T3, T3, '.', label='T3 = Magnet')
ax1.plot(t_T5, T5, '.', label='T5 = Still')
ax1.plot(t_T7, T7, '.', label='T7 = FMR/MXC')
ax1.plot(t_T8, T8, '.', label='T8 = Sample')
ax1.grid(True)
ax1.set_ylabel('Temperature in K')
ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))

ax2.plot(t_p, p1, '.', label='P1 = OVC')
ax2.plot(t_p, p2, '.', label='P2 = Still')
ax2.plot(t_p, p3, '.', label='P3 = Condensor')
ax2.plot(t_p, p4, '.', label='P4 = Before TRAP')
ax2.plot(t_p, p5, '.', label='P5 = Mixture TANK')
ax2.semilogy(t_p, p6, '.', label='P6 = Pipes to OVC')
ax2.grid(True)
ax2.set_xlabel('Date-Time')
ax2.set_ylabel('Pressure in mbar')
ax2.legend()
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
