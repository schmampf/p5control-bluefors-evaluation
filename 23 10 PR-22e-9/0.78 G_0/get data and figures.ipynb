# %% [markdown]
# # PR-22e-09 - Evaluation
# ### $G  = 0.78\,G_0$
# ### $\tau_i = \{???\}$

# %% [markdown]
# - 2023-10-21_MWIV_antenna_powers_frequencies_1_G0_again.hdf5
# - 2023-10-21_MWIV_antenna_powers_frequencies_1_G0.hdf5
# - 2023-10-21_MWIV_antenna_powers_maps_1_G0.hdf5
# - 2023-10-21_MWIV_stripline_powers_frequencies_1_G0.hdf5
# - 2023-10-21_MWIV_stripline_powers_maps_1_G0.hdf5
#
# Apparently "frequency_at_-25dBm" is crossed out in table of patrick.

# %%
# initialize stuff
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
import importlib
import logging

import numpy as np
import matplotlib.pyplot as plt

sys.path.append("/Users/oliver/Documents/p5control-bluefors-evaluation")
sys.path.append("/home/oliver/Documents/p5control-bluefors-evaluation")

from utilities.baseclass import BaseClass
from utilities.baseevaluation import BaseEvaluation
from utilities.baseplot import BasePlot
from utilities.ivevaluation import IVEvaluation

importlib.reload(sys.modules["utilities.baseclass"])
importlib.reload(sys.modules["utilities.baseevaluation"])
importlib.reload(sys.modules["utilities.baseplot"])
importlib.reload(sys.modules["utilities.ivevaluation"])

import utilities.basefunctions
importlib.reload(sys.modules["utilities.basefunctions"])

from utilities.corporate_design_colors_v4 import cmap
importlib.reload(sys.modules["utilities.corporate_design_colors_v4"])

importlib.reload(logging)
logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO, format="%(message)s")
# pip install numpy matplotlib scipy tqdm torch hdf5view h5py PySide6

# %%
# Settings of Evaluation
from utilities.ivevaluation import IVEvaluation

importlib.reload(sys.modules["utilities.ivevaluation"])

eva = IVEvaluation()
eva.file_directory = "/Volumes/speedyboy/atomic-contact/"
eva.file_folder = "0.78 G_0/"
eva.setAmplifications(1000, 1000)
eva.setV(2e-3, voltage_bins=1000)
eva.setI(130e-9, current_bins=1000)
eva.downsample_frequency = 43

# just frequencies
eva.file_name = "2023-10-21_MWIV_antenna_powers_maps_1_G0.hdf5"
eva.showMeasurements()
eva.file_name = "2023-10-21_MWIV_stripline_powers_maps_1_G0.hdf5"
eva.showMeasurements()

# amplitudes
eva.file_name = "2023-10-21_MWIV_antenna_powers_frequencies_1_G0.hdf5"
eva.showMeasurements()
eva.file_name = "2023-10-21_MWIV_antenna_powers_frequencies_1_G0_again.hdf5"
eva.showMeasurements()
eva.file_name = "2023-10-21_MWIV_stripline_powers_frequencies_1_G0.hdf5"
eva.showMeasurements()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base eva) Available measurements:
# - "frequency_at_-20dBm"
# - "frequency_at_-25dBm"
# - "frequency_at_-30dBm"
# (base eva) Available measurements:
# - "frequency_at_-20dBm"
# - "frequency_at_-25dBm"
# - "frequency_at_-30dBm"
# (base eva) Available measurements:
# - "frequency_at_15GHz"
# - "frequency_at_19.3GHz"
# - "frequency_at_7.8GHz"
# (base eva) Available measurements:
# - "frequency_at_15GHz"
# - "frequency_at_19.3GHz"
# - "frequency_at_7.8GHz"
# (base eva) Available measurements:
# - "frequency_at_15GHz"
# - "frequency_at_19.3GHz"
# - "frequency_at_7.8GHz"

# %%
# Evaluation of Frequencies
from utilities.ivevaluation import IVEvaluation

importlib.reload(sys.modules["utilities.ivevaluation"])

eva = IVEvaluation()
eva.file_directory = "/Volumes/speedyboy/atomic-contact/"
eva.file_folder = "0.78 G_0/"
eva.setAmplifications(1000, 1000)
eva.setV(2e-3, voltage_bins=1000)
eva.setI(130e-9, current_bins=1000)
eva.downsample_frequency = 43

# eva.file_name = '2023-10-21_MWIV_antenna_powers_maps_1_G0.hdf5'
# eva.showMeasurements()

# Frequency Study (0.03V, Antenna)
eva.title = "Frequency Study (0.03V, Antenna)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-20dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
(eva.up_sweep,) = eva.getMaps([1])
eva.saveData()

# Frequency Study (0.02V, Antenna)
eva.title = "Frequency Study (0.02V, Antenna)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-25dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
(eva.up_sweep,) = eva.getMaps([1])
eva.saveData()

# Frequency Study (0.01V, Antenna)
eva.title = "Frequency Study (0.01V, Antenna)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-30dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
(eva.up_sweep,) = eva.getMaps([1])
eva.saveData()

eva.file_name = "2023-10-21_MWIV_stripline_powers_maps_1_G0.hdf5"
eva.showMeasurements()

# Frequency Study (0.03V, Stripline)
eva.title = "Frequency Study (0.03V, Stripline)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-20dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
(eva.up_sweep,) = eva.getMaps([1])
eva.saveData()

# Frequency Study (0.02V, Stripline)
eva.title = "Frequency Study (0.02V, Stripline)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-25dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
(eva.up_sweep,) = eva.getMaps([1])
eva.saveData()

# Frequency Study (0.01V, Stripline)
eva.title = "Frequency Study (0.01V, Stripline)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-30dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
(eva.up_sweep,) = eva.getMaps([1])
eva.saveData()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base eva) Available measurements:
# - "frequency_at_-20dBm"
# - "frequency_at_-25dBm"
# - "frequency_at_-30dBm"
# (base) Frequency Study (0.03V, Stripline)
# (base eva) Measurement keys preview: ['nu=0.000GHz', 'nu=0.100GHz', 'nu=9.800GHz', 'nu=9.900GHz']
# (iv eva) getBackupTemperature()
# Frequency Study (0.03V, Stripline)
# 100%|██████████| 201/201 [00:20<00:00,  9.62it/s]
# (base) saveData()
# (base) Frequency Study (0.02V, Stripline)
# (base eva) Measurement keys preview: ['nu=0.000GHz', 'nu=0.100GHz', 'nu=9.800GHz', 'nu=9.900GHz']
# Frequency Study (0.02V, Stripline)
# 100%|██████████| 201/201 [00:21<00:00,  9.52it/s]
# (base) saveData()
# (base) Frequency Study (0.01V, Stripline)
# (base eva) Measurement keys preview: ['nu=0.000GHz', 'nu=0.100GHz', 'nu=9.800GHz', 'nu=9.900GHz']
# Frequency Study (0.01V, Stripline)
# 100%|██████████| 201/201 [00:20<00:00,  9.68it/s]
# (base) saveData()

# %%
# Execute All Frequency Plotting
# %matplotlib inline
from utilities.ivplot import IVPlot
importlib.reload(sys.modules["utilities.ivplot"])
eva = IVPlot()

eva.title = "Frequency Study (0.03V, Antenna)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 20
eva.plot_T = False
eva.plot_all()
eva.plot_T = True
eva.plot_all()

eva.title = "Frequency Study (0.02V, Antenna)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 20
eva.plot_T = False
eva.plot_all()
eva.plot_T = True
eva.plot_all()

eva.title = "Frequency Study (0.01V, Antenna)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 20
eva.plot_T = False
eva.plot_all()
eva.plot_T = True
eva.plot_all()

eva.title = "Frequency Study (0.03V, Stripline)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 20
eva.plot_T = False
eva.plot_all()
eva.plot_T = True
eva.plot_all()

eva.title = "Frequency Study (0.02V, Stripline)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 20
eva.plot_T = False
eva.plot_all()
eva.plot_T = True
eva.plot_all()

eva.title = "Frequency Study (0.01V, Stripline)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 20
eva.plot_T = False
eva.plot_all()
eva.plot_T = True
eva.plot_all()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base) ... BaseClass initialized.
# (base plot) ... BasePlot initialized.
# (iv plot) ... IVPlot initialized.
# (base) Frequency Study (0.03V, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 20
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.02V, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 20
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.01V, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 20
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()

# %%
# Evaluation of Amplitudes
from utilities.ivevaluation import IVEvaluation

importlib.reload(sys.modules["utilities.ivevaluation"])

eva = IVEvaluation()
eva.file_directory = "/Volumes/speedyboy/atomic-contact/"
eva.file_folder = "0.78 G_0/"
eva.setAmplifications(1000, 1000)
eva.setV(2e-3, voltage_bins=1000)
eva.setI(130e-9, current_bins=1000)
eva.downsample_frequency = 43

eva.file_name = "2023-10-21_MWIV_stripline_powers_frequencies_1_G0.hdf5"
eva.showMeasurements()

# Amplitude Study (7.8GHz, Stripline)
eva.title = "Amplitude Study (7.8GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_7.8GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.addKey("nu=-31.0dBm", -1000)
(eva.up_sweep,) = eva.getMaps([1])
eva.setA(0, 0.09, 90)
(eva.up_sweep,) = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

# Amplitude Study (15GHz, Stripline)
eva.title = "Amplitude Study (15GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_15GHz")
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.addKey("nu=-31.0dBm", -1000)
(eva.up_sweep,) = eva.getMaps([1])
eva.setA(0, 0.09, 90)
(eva.up_sweep,) = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

# Amplitude Study (19.3GHz, Stripline)
eva.title = "Amplitude Study (19.3GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_19.3GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.addKey("nu=-31.0dBm", -1000)
(eva.up_sweep,) = eva.getMaps([1])
eva.setA(0, 0.09, 90)
(eva.up_sweep,) = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

eva.file_name = "2023-10-21_MWIV_antenna_powers_frequencies_1_G0_again.hdf5"
eva.showMeasurements()

# Amplitude Study (7.8GHz, Antenna)
eva.title = "Amplitude Study (7.8GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_7.8GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.addKey("nu=-31.0dBm", -1000)
eva.eva_temperature = False
(eva.up_sweep,) = eva.getMaps([1])
eva.setA(0, 0.09, 90)
(eva.up_sweep,) = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

# Amplitude Study (15GHz, Antenna)
eva.title = "Amplitude Study (15GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_15GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.addKey("nu=-31.0dBm", -1000)
eva.eva_temperature = False
(eva.up_sweep,) = eva.getMaps([1])
eva.setA(0, 0.09, 90)
(eva.up_sweep,) = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

# Amplitude Study (19.3GHz, Antenna)
eva.title = "Amplitude Study (19.3GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_19.3GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.addKey("nu=-31.0dBm", -1000)
eva.eva_temperature = False
(eva.up_sweep,) = eva.getMaps([1])
eva.setA(0, 0.09, 90)
(eva.up_sweep,) = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base eva) Available measurements:
# - "frequency_at_15GHz"
# - "frequency_at_19.3GHz"
# - "frequency_at_7.8GHz"
# (base) Amplitude Study (7.8GHz, Stripline)
# (base eva) Measurement keys preview: ['nu=-10.0dBm', 'nu=-11.0dBm', 'nu=-30.0dBm', 'nu=-31.0dBm']
# (iv eva) getBackupTemperature()
# Amplitude Study (7.8GHz, Stripline)
# 100%|██████████| 23/23 [00:02<00:00,  8.30it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base) Amplitude Study (15GHz, Stripline)
# Amplitude Study (15GHz, Stripline)
# 100%|██████████| 23/23 [00:02<00:00,  8.52it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base) Amplitude Study (19.3GHz, Stripline)
# (base eva) Measurement keys preview: ['nu=-10.0dBm', 'nu=-11.0dBm', 'nu=-30.0dBm', 'nu=-31.0dBm']
# Amplitude Study (19.3GHz, Stripline)
# 100%|██████████| 23/23 [00:02<00:00,  8.96it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base eva) Available measurements:
# - "frequency_at_15GHz"
# - "frequency_at_19.3GHz"
# - "frequency_at_7.8GHz"
# (base) Amplitude Study (7.8GHz, Antenna)
# (base eva) Measurement keys preview: ['nu=-10.0dBm', 'nu=-11.0dBm', 'nu=-30.0dBm', 'nu=-31.0dBm']
# Amplitude Study (7.8GHz, Antenna)
# 100%|██████████| 23/23 [00:02<00:00,  8.69it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base) Amplitude Study (15GHz, Antenna)
# (base eva) Measurement keys preview: ['nu=-10.0dBm', 'nu=-11.0dBm', 'nu=-30.0dBm', 'nu=-31.0dBm']
# Amplitude Study (15GHz, Antenna)
# 100%|██████████| 23/23 [00:02<00:00,  8.71it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base) Amplitude Study (19.3GHz, Antenna)
# (base eva) Measurement keys preview: ['nu=-10.0dBm', 'nu=-11.0dBm', 'nu=-30.0dBm', 'nu=-31.0dBm']
# Amplitude Study (19.3GHz, Antenna)
# 100%|██████████| 23/23 [00:02<00:00,  8.58it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()

# %%
# Execute All Amplitude Plotting
# %matplotlib inline
from utilities.ivplot import IVPlot
importlib.reload(sys.modules["utilities.ivplot"])

eva = IVPlot()
eva.title = "Amplitude Study (7.8GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()

eva.title = "Amplitude Study (15GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()

eva.title = "Amplitude Study (19.3GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()


eva.title = "Amplitude Study (7.8GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()
eva.plot_T = True
eva.plot_all()

eva.title = "Amplitude Study (15GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()
eva.plot_T = True
eva.plot_all()

eva.title = "Amplitude Study (19.3GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()
eva.plot_T = True
eva.plot_all()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base) ... BaseClass initialized.
# (base plot) ... BasePlot initialized.
# (iv plot) ... IVPlot initialized.
# (base) Amplitude Study (7.8GHz, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (7.8GHz, Antenna)
# (base plot) saveFigure()
# (base) Amplitude Study (15GHz, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (15GHz, Antenna)
# (base plot) saveFigure()
# (base) Amplitude Study (19.3GHz, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (19.3GHz, Antenna)
# (base plot) saveFigure()
# (base) Amplitude Study (7.8GHz, Stripline)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (7.8GHz, Stripline)
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Amplitude Study (15GHz, Stripline)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (15GHz, Stripline)
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Amplitude Study (19.3GHz, Stripline)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (19.3GHz, Stripline)
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
