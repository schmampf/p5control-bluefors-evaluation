# %% [markdown]
# # PR-22e-09 - Evaluation
# ### $G  = 43\,G_0$
# ### $\tau_i = \{???\}$

# %% [markdown]
# - S2b: 23.777 G_0-542 Ohm	magnet	HIV-Map-19	False	2023-10-19_HIV_25_G0	2023-10-19_HIV_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	microwave	MWIV-Map-27	False	2023-10-20-MWIV_powers_maps	2023-10-19_MWIV_antenna_powers_maps_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	microwave	MWIV-Map-28	False	2023-10-20-MWIV_powers_maps	2023-10-19_MWIV_antenna_powers_maps_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	microwave	MWIV-Map-29	False	2023-10-20-MWIV_powers_maps	2023-10-19_MWIV_stripline_powers_maps_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	microwave	MWIV-Map-30	False	2023-10-20-MWIV_powers_maps	2023-10-19_MWIV_stripline_powers_maps_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	power	PMWIV-Map-3	False	2023-10-20-MWIV-powers	2023-10-20_MWIV_antenna_powers_frequencies_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	power	PMWIV-Map-4	False	2023-10-20-MWIV-powers	2023-10-20_MWIV_antenna_powers_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	power	PMWIV-Map-5	False	2023-10-20-MWIV-powers	2023-10-20_MWIV_antenna_powers_frequencies_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	power	PMWIV-Map-6	False	2023-10-20-MWIV-powers	2023-10-20_MWIV_stripline_powers_frequencies_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	power	PMWIV-Map-7	False	2023-10-20-MWIV-powers	2023-10-20_MWIV_stripline_powers_25_G0_0.hdf5
# - S2b: 23.777 G_0-542 Ohm	power	PMWIV-Map-8	False	2023-10-20-MWIV-powers	2023-10-20_MWIV_stripline_powers_frequencies_25_G0_0.hdf5

# %%
# initialize stuff
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
import importlib
import logging

import numpy as np
import matplotlib.pyplot as plt

sys.path.append("/Users/oliver/Documents/p5control-bluefors-evaluation")
sys.path.append("/home/oliver/Documents/p5control-bluefors-evaluation")

from utilities.baseclass import BaseClass
from utilities.baseevaluation import BaseEvaluation
from utilities.baseplot import BasePlot
from utilities.ivevaluation import IVEvaluation

importlib.reload(sys.modules["utilities.baseclass"])
importlib.reload(sys.modules["utilities.baseevaluation"])
importlib.reload(sys.modules["utilities.baseplot"])
importlib.reload(sys.modules["utilities.ivevaluation"])

import utilities.basefunctions
importlib.reload(sys.modules["utilities.basefunctions"])

from utilities.corporate_design_colors_v4 import cmap
importlib.reload(sys.modules["utilities.corporate_design_colors_v4"])

importlib.reload(logging)
logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO, format="%(message)s")
# pip install numpy matplotlib scipy tqdm torch hdf5view h5py PySide6

# %%
# Evaluation for power studies
from utilities.ivevaluation import IVEvaluation
importlib.reload(sys.modules["utilities.ivevaluation"])

eva = IVEvaluation()
eva.file_directory = '/Volumes/speedyboy/measurement data 2/'
eva.file_folder = '2023-10-20-MWIV-powers/'
eva.file_name = '2023-10-20_MWIV_Stripline_powers_25_G0_0.hdf5'

eva.setAmplifications(10000, 100)
eva.setV(.7e-3, voltage_bins=400)
eva.setI(2000e-9, current_bins=1000)
eva.showMeasurements()

eva.downsample_frequency = 43

# Amplitude Study (15GHz, Antenna)
eva.title = "Amplitude Study (15GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_15GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.eva_temperature = False
eva.up_sweep, = eva.getMaps([1])
eva.setA(0, 0.25, 250)
eva.up_sweep, = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

eva.file_name = '2023-10-20_MWIV_antenna_powers_frequencies_25_G0_0.hdf5'
eva.showMeasurements()

# Amplitude Study (7.8GHz, Antenna)
eva.title = "Amplitude Study (7.8GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_7.8GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.up_sweep, = eva.getMaps([1])
eva.setA(0, 0.09, 90)
eva.up_sweep, = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

# Amplitude Study (19.3GHz, Antenna)
eva.title = "Amplitude Study (19.3GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_19.3GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.up_sweep, = eva.getMaps([1])
eva.setA(0, 0.09, 90)
eva.up_sweep, = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

eva.file_name = '2023-10-20_MWIV_stripline_powers_25_G0_0.hdf5'

# Amplitude Study (15GHz, Stripline)
eva.title = "Amplitude Study (15GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_15GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.eva_temperature = False
eva.up_sweep, = eva.getMaps([1])
eva.setA(0, 0.25, 250)
eva.up_sweep, = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

eva.file_name = '2023-10-20_MWIV_stripline_powers_frequencies_25_G0_0.hdf5'
eva.showMeasurements()

# Amplitude Study (7.8GHz, Stripline)
eva.title = "Amplitude Study (7.8GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_7.8GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.up_sweep, = eva.getMaps([1])
eva.setA(0, 0.09, 90)
eva.up_sweep, = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

# Amplitude Study (19.3GHz, Stripline)
eva.title = "Amplitude Study (19.3GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.setMeasurement("frequency_at_19.3GHz")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.up_sweep, = eva.getMaps([1])
eva.setA(0, 0.09, 90)
eva.up_sweep, = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base eva) Available measurements:
# - "frequency_at_15GHz"
# (base) Amplitude Study (15GHz, Stripline)
# (base eva) Measurement keys preview: ['nu=-1.0dBm', 'nu=-10.0dBm', 'nu=-9.0dBm', 'nu=0.0dBm']
# (iv eva) getBackupTemperature()
# Amplitude Study (15GHz, Stripline)
# 100%|██████████| 32/32 [00:01<00:00, 20.33it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base eva) Available measurements:
# - "frequency_at_19.3GHz"
# - "frequency_at_7.8GHz"
# (base) Amplitude Study (7.8GHz, Antenna)
# (base eva) Measurement keys preview: ['nu=-10.0dBm', 'nu=-11.0dBm', 'nu=-30.0dBm', 'nu=-31.0dBm']
# Amplitude Study (7.8GHz, Antenna)
# 100%|██████████| 22/22 [00:00<00:00, 34.85it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base) Amplitude Study (19.3GHz, Antenna)
# (base eva) Measurement keys preview: ['nu=-10.0dBm', 'nu=-11.0dBm', 'nu=-30.0dBm', 'nu=-31.0dBm']
# Amplitude Study (19.3GHz, Antenna)
# 100%|██████████| 22/22 [00:00<00:00, 35.20it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base) Amplitude Study (15GHz, Stripline)
# (base eva) Measurement keys preview: ['nu=-1.0dBm', 'nu=-10.0dBm', 'nu=-9.0dBm', 'nu=0.0dBm']
# Amplitude Study (15GHz, Stripline)
# 100%|██████████| 32/32 [00:00<00:00, 39.95it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base eva) Available measurements:
# - "frequency_at_19.3GHz"
# - "frequency_at_7.8GHz"
# (base) Amplitude Study (7.8GHz, Stripline)
# (base eva) Measurement keys preview: ['nu=-10.0dBm', 'nu=-11.0dBm', 'nu=-30.0dBm', 'nu=-31.0dBm']
# Amplitude Study (7.8GHz, Stripline)
# 100%|██████████| 22/22 [00:00<00:00, 34.87it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base) Amplitude Study (19.3GHz, Stripline)
# (base eva) Measurement keys preview: ['nu=-10.0dBm', 'nu=-11.0dBm', 'nu=-30.0dBm', 'nu=-31.0dBm']
# Amplitude Study (19.3GHz, Stripline)
# 100%|██████████| 22/22 [00:00<00:00, 35.20it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()

# %%
# Execute All IVPlotting for power studies
# %matplotlib inline
from utilities.ivplot import IVPlot
importlib.reload(sys.modules["utilities.ivplot"])

eva = IVPlot()
eva.title = "Amplitude Study (7.8GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()

eva.title = "Amplitude Study (15GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()

eva.title = "Amplitude Study (19.3GHz, Antenna)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()


eva.title = "Amplitude Study (7.8GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()

eva.title = "Amplitude Study (15GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()

eva.title = "Amplitude Study (19.3GHz, Stripline)"
print(eva.title)
eva.sub_folder = "amplitude study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base) ... BaseClass initialized.
# (base plot) ... BasePlot initialized.
# (iv plot) ... IVPlot initialized.
# (base) Amplitude Study (7.8GHz, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (7.8GHz, Antenna)
# (base plot) saveFigure()
# (base) Amplitude Study (15GHz, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (15GHz, Antenna)
# (base plot) saveFigure()
# (base) Amplitude Study (19.3GHz, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (19.3GHz, Antenna)
# (base plot) saveFigure()
# (base) Amplitude Study (7.8GHz, Stripline)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (7.8GHz, Stripline)
# (base plot) saveFigure()
# (base) Amplitude Study (15GHz, Stripline)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (15GHz, Stripline)
# (base plot) saveFigure()
# (base) Amplitude Study (19.3GHz, Stripline)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# Amplitude Study (19.3GHz, Stripline)
# (base plot) saveFigure()

# %%
# Evaluation for frequency studies
from utilities.ivevaluation import IVEvaluation
importlib.reload(sys.modules["utilities.ivevaluation"])

eva = IVEvaluation()
eva.file_directory = '/Volumes/speedyboy/measurement data 2/'
eva.file_folder = '2023-10-20-MWIV_powers_maps/'

eva.setAmplifications(10000, 100)
eva.setV(.7e-3, voltage_bins=400)
eva.setI(2000e-9, current_bins=1000)

eva.downsample_frequency = 43

eva.file_name = '2023-10-19_MWIV_antenna_powers_maps_25_G0_0.hdf5'
eva.showMeasurements()

# Frequency Study (0.03V, Antenna)
eva.title = "Frequency Study (0.03V, Antenna)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-20dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
eva.eva_temperature = True
eva.up_sweep, = eva.getMaps([1])
eva.saveData()

# Frequency Study (0.01V, Antenna)
eva.title = "Frequency Study (0.01V, Antenna)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-30dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
eva.eva_temperature = True
eva.up_sweep, = eva.getMaps([1])
eva.saveData()


eva.file_name = '2023-10-19_MWIV_stripline_powers_maps_25_G0_0.hdf5'
eva.showMeasurements()

# Frequency Study (0.03V, Stripline)
eva.title = "Frequency Study (0.03V, Stripline)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-20dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
eva.eva_temperature = False
eva.up_sweep, = eva.getMaps([1])
eva.saveData()

# Frequency Study (0.01V, Stripline)
eva.title = "Frequency Study (0.01V, Stripline)"
print(eva.title)
eva.sub_folder = "frequency study"
eva.setMeasurement("frequency_at_-30dBm")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
eva.eva_temperature = False
eva.up_sweep, = eva.getMaps([1])
eva.saveData()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base eva) Available measurements:
# - "frequency_at_-20dBm"
# - "frequency_at_-30dBm"
# (base) Frequency Study (0.03V, Antenna)
# (base eva) Measurement keys preview: ['nu=0.000GHz', 'nu=0.100GHz', 'nu=9.800GHz', 'nu=9.900GHz']
# (iv eva) getBackupTemperature()
# Frequency Study (0.03V, Antenna)
# 100%|██████████| 201/201 [00:05<00:00, 39.84it/s]
# (base) saveData()
# (base) Frequency Study (0.01V, Antenna)
# (base eva) Measurement keys preview: ['nu=0.000GHz', 'nu=0.100GHz', 'nu=9.800GHz', 'nu=9.900GHz']
# Frequency Study (0.01V, Antenna)
# 100%|██████████| 201/201 [00:04<00:00, 41.16it/s]
# (base) saveData()
# (base eva) Available measurements:
# - "frequency_at_-20dBm"
# - "frequency_at_-30dBm"
# (base) Frequency Study (0.03V, Stripline)
# (base eva) Measurement keys preview: ['nu=0.000GHz', 'nu=0.100GHz', 'nu=9.800GHz', 'nu=9.900GHz']
# Frequency Study (0.03V, Stripline)
# 100%|██████████| 201/201 [00:05<00:00, 34.81it/s]
# /Users/oliver/Documents/p5control-bluefors-evaluation/utilities/ivevaluation.py:790: RuntimeWarning: Mean of empty slice
#   dictionary["temperature"] = np.nanmean(
# /Users/oliver/Documents/p5control-bluefors-evaluation/utilities/ivevaluation.py:801: RuntimeWarning: Mean of empty slice
#   dictionary["temperature"] = np.nanmean(
# (base) saveData()
# (base) Frequency Study (0.01V, Stripline)
# (base eva) Measurement keys preview: ['nu=0.000GHz', 'nu=0.100GHz', 'nu=9.800GHz', 'nu=9.900GHz']
# Frequency Study (0.01V, Stripline)
# 100%|██████████| 201/201 [00:04<00:00, 41.85it/s]
# (base) saveData()

# %%
# Execute All IVPlotting for frequency studies
# %matplotlib inline
from utilities.ivplot import IVPlot
importlib.reload(sys.modules["utilities.ivplot"])

eva = IVPlot()
eva.title = "Frequency Study (0.03V, Antenna)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = True
eva.plot_all()
eva.plot_T = False
eva.plot_all()

eva.title = "Frequency Study (0.01V, Antenna)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = True
eva.plot_all()
eva.plot_T = False
eva.plot_all()

eva.title = "Frequency Study (0.03V, Stripline)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()

eva.title = "Frequency Study (0.01V, Stripline)"
eva.sub_folder = "frequency study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
eva.plot_all()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base) ... BaseClass initialized.
# (base plot) ... BasePlot initialized.
# (iv plot) ... IVPlot initialized.
# (base) Frequency Study (0.03V, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.01V, Antenna)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.03V, Stripline)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.01V, Stripline)
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# (base plot) saveFigure()

# %%
# Evaluation for magnetic fiels study
from utilities.ivevaluation import IVEvaluation
importlib.reload(sys.modules["utilities.ivevaluation"])

eva = IVEvaluation()
eva.file_directory = '/Volumes/speedyboy/measurement data 2/'
eva.file_folder = '2023-10-19_HIV_25_G0/'

eva.setAmplifications(10000, 100)
eva.setV(.7e-3, voltage_bins=400)
eva.setI(2000e-9, current_bins=1000)

eva.downsample_frequency = 43

eva.file_name = '2023-10-19_HIV_25_G0_0.hdf5'
eva.showMeasurements()

# Magnetic Field Study
eva.title = "Magnetic Field Study"
print(eva.title)
eva.sub_folder = "magnetic field study"
eva.setMeasurement("critical field")
eva.showKeys()
eva.setKeys(index_0=3, index_1=-2, norm=1e-3)
eva.eva_temperature = True
eva.up_sweep, = eva.getMaps([1])
eva.saveData()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base eva) Available measurements:
# - "critical field"
# (base) Magnetic Field Study
# (base eva) Measurement keys preview: ['uH=+0.00mT', 'uH=+0.25mT', 'uH=-9.50mT', 'uH=-9.75mT']
# (iv eva) getBackupTemperature()
# Magnetic Field Study
# 100%|██████████| 241/241 [00:04<00:00, 48.99it/s]
# (base) saveData()

# %%
# Execute All IVPlotting for magnetic field study
# %matplotlib inline
from utilities.ivplot import IVPlot
importlib.reload(sys.modules["utilities.ivplot"])

eva = IVPlot()
eva.title = "Magnetic Field Study"
eva.sub_folder = "magnetic field study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.title_of_plot = "Up Sweep"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]
eva.smoothing = True
eva.window_length = 5
eva.plot_T = True
eva.plot_all()
eva.plot_T = False
eva.plot_all()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base) ... BaseClass initialized.
# (base plot) ... BasePlot initialized.
# (iv plot) ... IVPlot initialized.
# (base) Magnetic Field Study
# (base) loadData()
# (iv plot) smoothing = True
# (iv plot) window_length = 5
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base plot) saveFigure()
