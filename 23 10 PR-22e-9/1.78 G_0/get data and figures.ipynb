# %% [markdown]
# # PR-22e-09 - Evaluation
# ### $G  = 1.78\,G_0$
# ### $\tau_i = \{???\}$

# %% [markdown]
# - 2023-10-18_MWIV_stripline_tests_2_G0_0.hdf5
# - 2023-10-17_breaking_0.hdf5
# - 2023-10-17_HIV_2_G0_0.hdf5
# - 2023-10-17_MWIV_stripline_-20_dBm_2_G0_0.hdf5
# - 2023-10-18_MWIV_antenna_-20_dBm_2_G0_0.hdf5
# - 2023-10-18_MWIV_antenna_powers_2_G0_0.hdf5
# - 2023-10-18_MWIV_antenna_powers_maps_2_G0_0.hdf5
# - 2023-10-18_MWIV_antenna_tests_2_G0_0.hdf5
# - 2023-10-18_MWIV_antenna_tests_2_G0_1.hdf5
# - 2023-10-18_MWIV_stripline_powers_2_G0_0.hdf5
# - 2023-10-18_MWIV_stripline_powers_maps_2_G0_0.hdf5

# %%
# initialize stuff
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
import importlib
import logging

import numpy as np
import matplotlib.pyplot as plt

sys.path.append("/Users/oliver/Documents/p5control-bluefors-evaluation")
sys.path.append("/home/oliver/Documents/p5control-bluefors-evaluation")

from utilities.baseclass import BaseClass
from utilities.baseevaluation import BaseEvaluation
from utilities.baseplot import BasePlot
from utilities.ivevaluation import IVEvaluation

importlib.reload(sys.modules["utilities.baseclass"])
importlib.reload(sys.modules["utilities.baseevaluation"])
importlib.reload(sys.modules["utilities.baseplot"])
importlib.reload(sys.modules["utilities.ivevaluation"])

import utilities.basefunctions
importlib.reload(sys.modules["utilities.basefunctions"])

from utilities.corporate_design_colors_v4 import cmap
importlib.reload(sys.modules["utilities.corporate_design_colors_v4"])

importlib.reload(logging)
logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO, format="%(message)s")
# pip install numpy matplotlib scipy tqdm torch hdf5view h5py PySide6

# %%
# Settings of Evaluation
from utilities.ivevaluation import IVEvaluation

importlib.reload(sys.modules["utilities.ivevaluation"])

eva = IVEvaluation()
eva.file_directory = "/Volumes/speedyboy/atomic-contact/"
eva.file_folder = "1.78 G_0/"
eva.setAmplifications(10000, 1000)
eva.setV(0.7e-3, voltage_bins=1000)
eva.setI(90e-9, current_bins=1000)
eva.downsample_frequency = 43

# quatsch
# eva.file_name = "2023-10-18_MWIV_stripline_tests_2_G0_0.hdf5"
# eva.showMeasurements()
# eva.file_name = "2023-10-17_breaking_0.hdf5"
# eva.showMeasurements()
# eva.file_name = "2023-10-18_MWIV_antenna_tests_2_G0_0.hdf5"
# eva.showMeasurements()
# eva.file_name = "2023-10-18_MWIV_antenna_tests_2_G0_1.hdf5"
# eva.showMeasurements()

# critical field
eva.file_name = "2023-10-17_HIV_2_G0_0.hdf5"
eva.showMeasurements()

# frequencies
eva.file_name = "2023-10-18_MWIV_antenna_-20_dBm_2_G0_0.hdf5"
eva.showMeasurements()
eva.file_name = "2023-10-18_MWIV_antenna_powers_maps_2_G0_0.hdf5"
eva.showMeasurements()
eva.file_name = "2023-10-17_MWIV_stripline_-20_dBm_2_G0_0.hdf5"
eva.showMeasurements()
eva.file_name = "2023-10-18_MWIV_stripline_powers_maps_2_G0_0.hdf5"
eva.showMeasurements()

# amplitudes
eva.file_name = "2023-10-18_MWIV_stripline_powers_2_G0_0.hdf5"
eva.showMeasurements()
eva.file_name = "2023-10-18_MWIV_antenna_powers_2_G0_0.hdf5"
eva.showMeasurements()
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base eva) Available measurements:
# - "critical field"
# - "critical field test"
# - "m000000"
# - "test"
# (base eva) Available measurements:
# - "frequency_at_-20dBm"
# (base eva) Available measurements:
# - "frequency_at_-15dBm"
# - "frequency_at_-25dBm"
# - "frequency_at_-30dBm"
# (base eva) Available measurements:
# - "frequency_at_-20dBm"
# (base eva) Available measurements:
# - "frequency_at_-15dBm"
# - "frequency_at_-25dBm"
# - "frequency_at_-30dBm"
# (base eva) Available measurements:
# - "frequency_at_15GHz"
# (base eva) Available measurements:
# - "frequency_at_15GHz"

# %%
# Evaluating Amplitude Studies
eva.sub_folder = "amplitude study"
eva.setA(0, 0.09, 90)
eva.eva_temperature = False

eva.file_name = "2023-10-18_MWIV_antenna_powers_2_G0_0.hdf5"

eva.title = "Amplitude Study (15GHz, Antenna)"
eva.setMeasurement("frequency_at_15GHz")
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.addKey("nu=-31.0dBm", -1000)
(eva.up_sweep,) = eva.getMaps([1])
(eva.up_sweep,) = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()

eva.file_name = "2023-10-18_MWIV_stripline_powers_2_G0_0.hdf5"

eva.title = "Amplitude Study (15GHz, Stripline)"
eva.setMeasurement("frequency_at_15GHz")
eva.setKeys(index_0=3, index_1=-3, norm=1)
eva.addKey("nu=-31.0dBm", -1000)
(eva.up_sweep,) = eva.getMaps([1])
(eva.up_sweep,) = eva.getMapsAmplitude([eva.up_sweep])
eva.y_axis = eva.amplitude_axis
eva.saveData()
# Out:
# (base) Amplitude Study (15GHz, Antenna)
# 100%|██████████| 23/23 [00:02<00:00,  8.67it/s]
# /Users/oliver/Documents/p5control-bluefors-evaluation/utilities/ivevaluation.py:790: RuntimeWarning: Mean of empty slice
#   dictionary["temperature"] = np.nanmean(
# /Users/oliver/Documents/p5control-bluefors-evaluation/utilities/ivevaluation.py:801: RuntimeWarning: Mean of empty slice
#   dictionary["temperature"] = np.nanmean(
# (iv eva) getMapsAmplitude()
# (base) saveData()
# (base) Amplitude Study (15GHz, Stripline)
# 100%|██████████| 23/23 [00:02<00:00,  8.62it/s]
# (iv eva) getMapsAmplitude()
# (base) saveData()

# %%
# Evaluating Frequency Studies

eva.sub_folder = "frequency study"
eva.eva_temperature = False

eva.setAmplifications(1000, 100)
eva.file_name = "2023-10-18_MWIV_antenna_-20_dBm_2_G0_0.hdf5"

eva.title = "Frequency Study (0.03V, Antenna)"
eva.setMeasurement("frequency_at_-20dBm")
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
(eva.up_sweep,) = eva.getMaps([1])
eva.saveData()

eva.file_name = "2023-10-17_MWIV_stripline_-20_dBm_2_G0_0.hdf5"

eva.title = "Frequency Study (0.03V, Stripline)"
eva.setMeasurement("frequency_at_-20dBm")
eva.setKeys(index_0=3, index_1=-3, norm=1e9)
(eva.up_sweep,) = eva.getMaps([1])
eva.saveData()

# eva.setAmplifications(10000, 1000)
# eva.file_name = "2023-10-18_MWIV_antenna_powers_maps_2_G0_0.hdf5"

# eva.title = "Frequency Study (0.04V, Antenna)"
# eva.setMeasurement("frequency_at_-15dBm")
# eva.setKeys(index_0=3, index_1=-3, norm=1e9)
# (eva.up_sweep,) = eva.getMaps([1])
# eva.saveData()

# eva.title = "Frequency Study (0.02V, Antenna)"
# eva.setMeasurement("frequency_at_-25dBm")
# eva.setKeys(index_0=3, index_1=-3, norm=1e9)
# (eva.up_sweep,) = eva.getMaps([1])
# eva.saveData()

# eva.title = "Frequency Study (0.01V, Antenna)"
# eva.setMeasurement("frequency_at_-30dBm")
# eva.setKeys(index_0=3, index_1=-3, norm=1e9)
# (eva.up_sweep,) = eva.getMaps([1])
# eva.saveData()

# eva.file_name = "2023-10-18_MWIV_stripline_powers_maps_2_G0_0.hdf5"

# eva.title = "Frequency Study (0.04V, Stripline)"
# eva.setMeasurement("frequency_at_-15dBm")
# eva.setKeys(index_0=3, index_1=-3, norm=1e9)
# (eva.up_sweep,) = eva.getMaps([1])
# eva.saveData()

# eva.title = "Frequency Study (0.02V, Stripline)"
# eva.setMeasurement("frequency_at_-25dBm")
# eva.setKeys(index_0=3, index_1=-3, norm=1e9)
# (eva.up_sweep,) = eva.getMaps([1])
# eva.saveData()

# eva.title = "Frequency Study (0.01V, Stripline)"
# eva.setMeasurement("frequency_at_-30dBm")
# eva.setKeys(index_0=3, index_1=-3, norm=1e9)
# (eva.up_sweep,) = eva.getMaps([1])
# eva.saveData()
# Out:
# (base) Frequency Study (0.03V, Antenna)
# 100%|██████████| 201/201 [00:20<00:00,  9.73it/s]
# (base) saveData()
# (base) Frequency Study (0.03V, Stripline)
# 100%|██████████| 401/401 [01:07<00:00,  5.91it/s]
# (base) saveData()

# %%
# Evaluating Magnetic Field Study

eva.sub_folder = "magnetic field study"
eva.eva_temperature = False

eva.file_name = "2023-10-17_HIV_2_G0_0.hdf5"

eva.title = "Magnetic Field Study"
eva.setMeasurement("critical field")
eva.setKeys(index_0=3, index_1=-2, norm=1e-3)
(eva.up_sweep,) = eva.getMaps([1])
eva.saveData()
# Out:
# (base) Magnetic Field Study
# 100%|██████████| 241/241 [00:57<00:00,  4.20it/s]
# (base) saveData()

# %%
# Plot Everything
# %matplotlib inline
from utilities.ivplot import IVPlot
importlib.reload(sys.modules["utilities.ivplot"])

eva = IVPlot()
eva.title_of_plot = "Up Sweep"
eva.smoothing = True
eva.window_length = 5
eva.plot_T = False
# Out:
# (base) ... BaseClass initialized.
# (base eva) ... BaseEvaluation initialized.
# (iv eva) ... IVEvaluation initialized.
# (base) ... BaseClass initialized.
# (base plot) ... BasePlot initialized.
# (iv plot) ... IVPlot initialized.
# (iv plot) smoothing = True
# (iv plot) window_length = 5

# %%
# Plot Amplitude Studies

eva.sub_folder = "amplitude study"
eva.y_characters = [r"$V_\mathrm{AC}$", "V"]

eva.title = "Amplitude Study (15GHz, Antenna)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()

eva.title = "Amplitude Study (15GHz, Stripline)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()
# Out:
# (base) Amplitude Study (15GHz, Antenna)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Amplitude Study (15GHz, Stripline)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()

# %%
# Plot Frequency Studies

eva.sub_folder = "frequency study"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]

eva.title = "Frequency Study (0.04V, Antenna)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()

eva.title = "Frequency Study (0.03V, Antenna)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()

eva.title = "Frequency Study (0.02V, Antenna)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()

eva.title = "Frequency Study (0.01V, Antenna)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()

eva.title = "Frequency Study (0.04V, Stripline)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()

eva.title = "Frequency Study (0.03V, Stripline)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()

eva.title = "Frequency Study (0.02V, Stripline)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()

eva.title = "Frequency Study (0.01V, Stripline)"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()
# Out:
# (base) Frequency Study (0.04V, Antenna)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.03V, Antenna)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.02V, Antenna)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.01V, Antenna)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.04V, Stripline)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.03V, Stripline)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.02V, Stripline)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()
# (base) Frequency Study (0.01V, Stripline)
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()

# %%
# Plot Magnetic Field Study

eva.sub_folder = "magnetic field study"
eva.y_characters = [r"$\nu_\mathrm{AC}$", "Hz"]

eva.title = "Magnetic Field Study"
eva.loadData()
eva.to_plot = eva.up_sweep
eva.plot_all()
# Out:
# (base) Magnetic Field Study
# (base) loadData()
# (base plot) saveFigure()
# (base plot) saveFigure()
