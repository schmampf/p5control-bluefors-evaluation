# %%
# %load_ext autoreload
# %autoreload 2

import sys, h5py, os, time
import numpy as np
import matplotlib.pyplot as plt

sys.path.append("/Users/oliver/Documents/evaluation")
from utilities.corporate_design_colors_v4 import cmap
from utilities import EvaluationScript_v2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Temperature Study

# %%
script = EvaluationScript_v2()
script.folder = '24 08 13 temperature study/'
script.fname  = 'OI-24d-10 24-08-13 temperature study 4.hdf5'
script.show_measurements()
script.set_measurement('temperatures')
script.show_amplifications()
script.set_amplifications(1000, 10000)
script.show_keys()
script.pop_key('no_power')
script.show_keys()
script.get_y()
# Out:
# Available Measurements:
# 'temperatures'
# Measurement: 'temperatures'
# Showing Femto Amplifications according to Status below.
# TODO: implement datetime, probably two axes
# Set Amplification to 1000 & 10000.
# Keys are for example:
# ['heater_000.0µW', 'heater_000.1µW', 'heater_000.2µW', 'heater_000.4µW']
# ['no_power', 'heater_984.4µW', 'heater_958.7µW', 'heater_933.3µW']
# Remove: 'no_power'.
# Keys are for example:
# ['heater_000.0µW', 'heater_000.1µW', 'heater_000.2µW', 'heater_000.4µW']
# ['heater_984.4µW', 'heater_958.7µW', 'heater_933.3µW', 'heater_908.4µW']
# y-values are for example:
# [0.0e+00 1.0e-07 2.0e-07 4.0e-07 7.0e-07 1.1e-06 1.6e-06 2.2e-06]

# %%
script.set_V(V_abs = 1.2e-3, N_bins=600)
script.get_mapping_done()
script.map_over_T()
# Out:
# Set V_min = -0.0012, V_max = 0.0012 & N_bins = 600.
# Start with mapping. Progress:
# 100%|██████████| 130/130 [00:08<00:00, 15.45it/s]
# Mapping over T.

# %%
script.title = 'OI-24d-10, unbroken, Temperature Study'
script.show_map(
    x_key = 'V_bias_up_mV',
    y_key = 'T_binned_up_K',
    z_key = 'dIdV_up_T',
    x_lim = [-1.2, 1.2],
    y_lim = [0.1, 1.4],
    z_lim = [0, 0.2],
)

# %%
script = EvaluationScript_v2()
script.folder = '24 08 13 temperature study/'
script.fname  = 'OI-24d-10 24-08-13 temperature study 4.hdf5'
# script.show_measurements()
script.set_measurement('temperatures')
# script.show_amplifications()
script.set_amplifications(1000, 10000)
# script.show_keys()
script.get_y()
script.set_V(V_abs = 1.2e-3, N_bins=600)
script.get_mapping_done()
script.map_over_T()
# Out:
# Measurement: 'temperatures'
# Set Amplification to 1000 & 10000.
# y-values are for example:
# [0.0e+00 1.0e-07 2.0e-07 4.0e-07 7.0e-07 1.1e-06 1.6e-06 2.2e-06]
# Set V_min = -0.0012, V_max = 0.0012 & N_bins = 600.
# Start with mapping. Progress:
# 100%|██████████| 130/130 [00:04<00:00, 27.53it/s]
# Mapping over T.

# %%
script.title = 'Temperature Study (0.1K to 1.4K)'
script.show_map(
    x_key = 'V_bias_down_mV',
    y_key = 'T_binned_up_K',
    z_key = 'dIdV_down_T',
    x_lim = [-1.2, 1.2],
    y_lim = [0.1, 1.4],
    z_lim = [0, 0.2],
)

# %%
script.save_figure()

script.get_dict_keys()
script. get_keys()
# Out:
# Figure is saved under: figures/Temperature Study (0.1K to 1.4K).png
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[125], line 4
#       1 script.save_figure()
#       3 script.get_dict_keys()
# ----> 4 script. get_keys()
#
# File ~/Documents/evaluation/utilities/evaluation_v2.py:546, in EvaluationScript_v2.get_keys(self)
#     545 def get_keys(self):
# --> 546     key = 'self.'+key
#     547     dict_keys = self.get_dict_keys()
#     548     dictionary = {}
#
# UnboundLocalError: cannot access local variable 'key' where it is not associated with a value

# %%
script = EvaluationScript_v2()
script.file_folder = '24 08 13 temperature study/'
script.file_name  = 'OI-24d-10 24-08-14 temperature study 5.hdf5'
script.show_measurements()
script.set_measurement('temperatures_up')
# script.show_amplifications()
script.set_amplifications(1000, 10000)
script.show_keys()
# script.pop_key('no_power')
# script.show_keys()
script.get_y(index={'temperatures_up':[7, -2, 1e-6, 'no_heater']})
script.set_V(V_abs = 1.2e-3, N_bins=600)
script.get_mapping_done()
script.map_over_T()
# Out:
# Available Measurements:
# 'temperatures_down'
# 'temperatures_up'
# Measurement: 'temperatures_up'
# Set Amplification to 1000 & 10000.
# Keys are for example:
# ['heater_00000.013µW', 'heater_00000.070µW', 'heater_00000.193µW', 'heater_00000.393µW']
# ['no_heater', 'heater_03135.622µW', 'heater_03084.056µW', 'heater_03032.999µW']
# y-values are for example:
# [1.300e-08 7.000e-08 1.930e-07 3.930e-07 6.830e-07 1.074e-06 1.573e-06
#  2.191e-06]
# Set V_min = -0.0012, V_max = 0.0012 & N_bins = 600.
# Start with mapping. Progress:
# 100%|██████████| 150/150 [00:05<00:00, 28.48it/s]
# Mapping over T.

# %%
script.title = 'Temperature Study (0.1K to 1.55K)'
script.show_map(
    x_key = 'V_bias_down_mV',
    y_key = 'T_binned_up_K',
    z_key = 'dIdV_down_T',
    x_lim = [-1.2, 1.2],
    y_lim = [0.1, 1.55],
    z_lim = [0, 0.2],
)

# %%
script = EvaluationScript_v2()
script.file_folder = '24 08 13 temperature study/'
script.file_name  = 'OI-24d-10 24-08-14 temperature study 9.hdf5'
script.show_measurements()
script.set_measurement('temperatures')
script.set_amplifications(1000, 10000)
script.show_keys()
script.get_y()
script.set_V(V_abs = 1.2e-3, N_bins=600)
script.get_mapping_done()
script.map_over_T()
# Out:
# Available Measurements:
# 'temperatures'
# Measurement: 'temperatures'
# Set Amplification to 1000 & 10000.
# Keys are for example:
# ['heater_00000.013muW', 'heater_00000.070muW', 'heater_00000.193muW', 'heater_00000.393muW']
# ['no_heater', 'heater_03135.622muW', 'heater_03084.056muW', 'heater_03032.999muW']
# y-values are for example:
# [1.300e-08 7.000e-08 1.930e-07 3.930e-07 6.830e-07 1.074e-06 1.573e-06
#  2.191e-06]
# Set V_min = -0.0012, V_max = 0.0012 & N_bins = 600.
# Start with mapping. Progress:
# 100%|██████████| 150/150 [00:05<00:00, 27.81it/s]
# Mapping over T.

# %%
script.title = 'Temperature Study (1.55K to 0.1K)'
script.show_map(
    x_key = 'V_bias_down_mV',
    y_key = 'T_binned_down_K',
    z_key = 'dIdV_down_T',
    x_lim = [-1.2, 1.2],
    y_lim = [0.1, 1.55],
    z_lim = [0, 0.2],
)
