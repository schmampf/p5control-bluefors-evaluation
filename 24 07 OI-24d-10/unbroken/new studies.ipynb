# %%
# initialize stuff
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("/Users/oliver/Documents/evaluation")
sys.path.append("/home/oliver/Documents/p5control-bluefors-evaluation")

from utilities.corporate_design_colors_v4 import cmap
from utilities.baseplotting import BasePlotting

import logging
from importlib import reload
logger = logging.getLogger(__name__)
reload(logging)
logging.basicConfig(level=logging.INFO, format='%(message)s')

# %% [markdown]
# # Evaluation

# %%
# Evaluate Magnetic Field Study (high res) (53s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.base["title"]='Magnetic Field Study (high res)'
eva.base["sub_folder"] = 'magnetic field studies/'
eva.file["folder"] = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file["name"]  = "OI-24d-10 24-09-05 magnetic field study 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('magnetic_fields')
eva.showKeys()
eva.setKeys()
eva.setV(1.1e-3, voltage_bins=1000)
eva.getMaps()
eva.saveData()
eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['magnetic_fields']
# (eva) setMeasurement('magnetic_fields')
# (eva) showKeys()
# (eva) ['magnet_+0.00mT', 'magnet_+1.00mT', 'magnet_-99.00mT', 'no_field']
# (eva) setKeys([7, -2, 0.001, 'no_field'])
# (eva) setV(-0.0011, 0.0011, 1000)
# (eva) getMaps()
# 100%|██████████| 241/241 [00:55<00:00,  4.32it/s]
# (eva) saveData()
# (eva) showData()
# {'base': {'title': 'Magnetic Field Study (high res)',
#   'sub_folder': 'magnetic field studies/',
#   'data_folder': 'data/',
#   'figure_folder': 'figures/',
#   'ignore_while_saving': ['_name']},
#  'file': {'directory': '/home/oliver/Documents/measurement_data/',
#   'folder': '24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/',
#   'name': 'OI-24d-10 24-09-05 magnetic field study 0.hdf5'},
# ...

# %%
# Plot Magnetic Field Study (high res)
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')

eva.base["title"]='Magnetic Field Study (high res)'
eva.base["sub_folder"] = 'magnetic field studies/'
eva.loadData()
eva.window_length = 30
eva.y_key = "uH_mT"
eva.y_lim = [-150, 150]
eva.x_lim = [-1, 1]
eva.z_lim = [0, .2]
eva.showMap()
eva.saveFigure()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) loadData()
# (eva) window_length = 30
# (eva) y_key = uH_mT
# (eva) y_lim = [-150, 150]
# (eva) x_lim = [-1, 1]
# (eva) z_lim = [0, 0.2]
# (eva) showMap('V_bias_up_mV', 'uH_mT', 'dIdV_up')
# (eva) saveFigure() to figures/Magnetic Field Study (high res).png

# %%
# Evaluate Magnetic Field Study (high res) (53s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.base["title"]='Amplitude Study at 7.8 GHz with Antenna'
eva.base["sub_folder"] = 'magnetic field studies/'
eva.file["folder"] = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file["name"]  = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.8000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.8000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.8000GHz_0.010V', 'vna_7.8000GHz_0.795V', 'vna_7.8000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) setV(-0.0013, 0.0013, 1000)
# (eva) getMaps()
# 100%|██████████| 159/159 [00:54<00:00,  2.93it/s]
# (eva) saveData()
# (eva) showData()
# {'base': {'title': 'Amplitude Study at 7.8GHz with Antenna',
#   'sub_folder': 'magnetic field studies/',
#   'data_folder': 'data/',
#   'figure_folder': 'figures/',
#   'ignore_while_saving': ['_name']},
#  'file': {'directory': '/home/oliver/Documents/measurement_data/',
#   'folder': '24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/',
# ...

# %%
# Plot Magnetic Field Study (high res)
# %matplotlib inline
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')

eva.base["title"]='Amplitude Study at 7.8 GHz with Antenna'
eva.base["sub_folder"] = 'magnetic field studies/'
eva.loadData()
eva.window_length = 10
eva.y_lim = [-0, 1]
eva.x_lim = [-1., 1.]
eva.z_lim = [0, .2]
eva.showMap()
eva.saveFigure()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) loadData()
# (eva) window_length = 10
# (eva) y_lim = [0, 1]
# (eva) x_lim = [-1.0, 1.0]
# (eva) z_lim = [0, 0.2]
# (eva) showMap('V_bias_up_mV', 'y_axis', 'dIdV_up')
# (eva) saveFigure() to figures/Amplitude Study at 7.8GHz with Antenna.png
