# %%
# initialize stuff
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("/Users/oliver/Documents/p5control-bluefors-evaluation")
sys.path.append("/home/oliver/Documents/p5control-bluefors-evaluation")

from utilities.corporate_design_colors_v4 import cmap
from utilities.baseplotting import BasePlotting

import logging
from importlib import reload
logger = logging.getLogger(__name__)
reload(logging)
logging.basicConfig(level=logging.INFO, format='%(message)s')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Evaluation

# %%
# Magnetic Field Study (high res) (20s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title='Magnetic Field Study (high res)'
eva.sub_folder = 'magnetic field studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name = "OI-24d-10 24-09-05 magnetic field study 0.hdf5"
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('magnetic_fields')
eva.showKeys()
eva.setKeys()
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showFile()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Magnetic Field Study (high res)
# (eva) sub_folder = magnetic field studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 magnetic field study 0.hdf5
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['magnetic_fields']
# (eva) setMeasurement('magnetic_fields')
# (eva) showKeys()
# (eva) ['magnet_+0.00mT', 'magnet_+1.00mT', 'magnet_-99.00mT', 'no_field']
# (eva) setKeys([7, -2, 0.001, 'no_field'])
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 241/241 [00:20<00:00, 11.82it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.8 GHz with Antenna (1m 4s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.base["title"]='Amplitude Study at 7.8 GHz with Antenna'
eva.base["sub_folder"] = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name  = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.8000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showFile()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.8000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.8000GHz_0.010V', 'vna_7.8000GHz_0.795V', 'vna_7.8000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [00:54<00:00,  2.95it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.7 GHz with Antenna (18.4 s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.base["title"]='Amplitude Study at 7.7 GHz with Antenna'
eva.base["sub_folder"] = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.7000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showFile()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.7000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.7000GHz_0.010V', 'vna_7.7000GHz_0.795V', 'vna_7.7000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [00:08<00:00, 17.93it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.9 GHz with Antenna (23.1 s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title='Amplitude Study at 7.9 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.9000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showFile()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 7.9 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.9000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.9000GHz_0.010V', 'vna_7.9000GHz_0.795V', 'vna_7.9000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [00:09<00:00, 16.91it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.8 GHz with Stripline (1m 10s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title='Amplitude Study at 7.8 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.8000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 7.8 GHz with Stripline
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.8000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.8000GHz_0.010V', 'vna_7.8000GHz_0.795V', 'vna_7.8000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [00:56<00:00,  2.85it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.7 GHz with Stripline (31s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 7.7 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.7000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.7000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.7000GHz_0.010V', 'vna_7.7000GHz_0.795V', 'vna_7.7000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [00:09<00:00, 16.66it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.9 GHz with Stripline (31s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 7.9 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name  = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.9000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.addKey(key="no_irradiation", y_value=0.005)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 7.9 GHz with Stripline
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.9000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.9000GHz_0.010V', 'vna_7.9000GHz_0.795V', 'vna_7.9000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 161/161 [00:09<00:00, 17.28it/s]
# (eva) saveData()

# %%
# Frequency Study at 0.4V with Antenna (54.5s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Frequency Study at 0.4V with Antenna'
eva.sub_folder = 'frequency studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 11 frequency study at 0.4V/"
eva.file_name  = "OI-24d-10 24-09-11 frequency study 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_frequencies_0.400V')
eva.showKeys()
eva.setKeys([4, -10, 1e9, "no_irradiation"])
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Frequency Study at 0.4V with Antenna
# (eva) sub_folder = frequency studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 11 frequency study at 0.4V/
# (eva) file_name = OI-24d-10 24-09-11 frequency study 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_frequencies_0.400V']
# (eva) setMeasurement('vna_frequencies_0.400V')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_1.0000GHz_0.400V', 'vna_9.8000GHz_0.400V', 'vna_9.9000GHz_0.400V']
# (eva) setKeys([4, -10, 1000000000.0, 'no_irradiation'])
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 191/191 [00:42<00:00,  4.53it/s]
# (eva) saveData()

# %%
# Amplitude Study at 12.1 GHz with Antenna (2)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 12.1 GHz with Antenna (2)'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/"
eva.file_name  = "OI-24d-10 24-09-13 amplitude study at 3.5GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_12.1000GHz')
eva.showKeys()
eva.setKeys([15, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.addKey(key="no_irradiation", y_value=0.005)
eva.setV(1.3e-3, voltage_bins=1300)
eva.upsampling = 100
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 12.1 GHz with Antenna (2)
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/
# (eva) file_name = OI-24d-10 24-09-13 amplitude study at 3.5GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_12.1000GHz']
# (eva) setMeasurement('vna_amplitudes_12.1000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_12.1000GHz_0.010V', 'vna_12.1000GHz_0.995V', 'vna_12.1000GHz_1.000V']
# (eva) setKeys([15, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) upsampling = 100
# (eva) getMaps()
# 100%|██████████| 201/201 [01:54<00:00,  1.76it/s]
# (eva) saveData()

# %%
# Amplitude Study at 12.1 GHz with Antenna (1m 47s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 12.1 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/"
eva.file_name  = "OI-24d-10 24-09-13 amplitude study at 12.1GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_12.1000GHz')
eva.showKeys()
eva.setKeys([15, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.addKey(key="no_irradiation", y_value=0.005)
eva.setV(1.3e-3, voltage_bins=1300)
eva.upsampling = 100
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 12.1 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/
# (eva) file_name = OI-24d-10 24-09-13 amplitude study at 12.1GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_12.1000GHz']
# (eva) setMeasurement('vna_amplitudes_12.1000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_12.1000GHz_0.010V', 'vna_12.1000GHz_0.995V', 'vna_12.1000GHz_1.000V']
# (eva) setKeys([15, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) upsampling = 100
# (eva) getMaps()
# 100%|██████████| 201/201 [01:44<00:00,  1.93it/s]
# (eva) saveData()

# %%
# Amplitude Study at 19.0 GHz with Antenna (1m 47s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 19.0 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/"
eva.file_name  = "OI-24d-10 24-09-13 amplitude study at 19GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_19.0000GHz')
eva.showKeys()
eva.setKeys([15, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.addKey(key="no_irradiation", y_value=0.005)
eva.setV(1.3e-3, voltage_bins=1300)
eva.upsampling = 100
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 19.0 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/
# (eva) file_name = OI-24d-10 24-09-13 amplitude study at 19GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_19.0000GHz']
# (eva) setMeasurement('vna_amplitudes_19.0000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_19.0000GHz_0.010V', 'vna_19.0000GHz_0.995V', 'vna_19.0000GHz_1.000V']
# (eva) setKeys([15, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) upsampling = 100
# (eva) getMaps()
# 100%|██████████| 201/201 [01:44<00:00,  1.92it/s]
# (eva) saveData()

# %% [markdown]
# ### Plotting

# %%
# Plot Magnetic Field Study (high res)
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')

eva.title='Magnetic Field Study (high res)'
eva.sub_folder= 'magnetic field studies/'
eva.loadData()
eva.window_length = 30
eva.y_key = "uH_mT"
eva.y_lim = [None, None]
eva.x_lim = [-1, 1]
eva.z_lim = [0, .2]

eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 50, -50, 100, -100])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Magnetic Field Study (high res)
# (eva) sub_folder = magnetic field studies/
# (eva) loadData()
# (eva) window_length = 30
# (eva) y_key = uH_mT
# (eva) y_lim = [None, None]
# (eva) x_lim = [-1, 1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'uH_mT', 'dIdV_up')
# (eva) saveMap() to figures/Magnetic Field Study (high res).png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'uH_mT', 'dIdV_up')
# (eva) saveMap() to figures/Magnetic Field Study (high res).png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'uH_mT', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Magnetic Field Study (high res).png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'uH_mT', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Magnetic Field Study (high res).png
# (eva) z_lim = [None, None]
# ...

# %%
# Plot Amplitude Study at 7.8 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.8 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.8 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) window_length = 10
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.8 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.8 GHz with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.8 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# ...

# %%
# Plot Amplitude Study at 7.7 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.7 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.7 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) window_length = 10
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.7 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.7 GHz with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.7 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# ...

# %%
# Plot Amplitude Study at 7.9 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.9 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.9 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) window_length = 10
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.9 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.9 GHz with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.9 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# ...

# %%
# Plot Amplitude Study at 7.8 GHz with Stripline
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.8 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.8 GHz with Stripline
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) window_length = 10
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.8 GHz with Stripline.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.8 GHz with Stripline.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.8 GHz with Stripline.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# ...

# %%
# Plot Amplitude Study at 7.7 GHz with Stripline
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.base["title"] = 'Amplitude Study at 7.7 GHz with Stripline'
eva.base["sub_folder"] = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.7 GHz with Stripline.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.7 GHz with Stripline.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.7 GHz with Stripline.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.7 GHz with Stripline.png
# (eva) z_lim = [None, None]
# ...

# %%
# Plot Amplitude Study at 7.9 GHz with Stripline
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.9 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.9 GHz with Stripline
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.9 GHz with Stripline.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.9 GHz with Stripline.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.9 GHz with Stripline.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.9 GHz with Stripline.png
# ...

# %%
# Plot Frequency Study at 0.4V with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Frequency Study at 0.4V with Antenna'
eva.sub_folder = 'frequency studies/'
eva.loadData()
eva.y_key = "nu_up"
eva.x_lim = [-1.4, 1.4]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[3.3, 4, 7.7, 14.4])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Frequency Study at 0.4V with Antenna
# (eva) sub_folder = frequency studies/
# (eva) loadData()
# (eva) y_key = nu_up
# (eva) x_lim = [-1.4, 1.4]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'nu_up', 'dIdV_up')
# (eva) saveMap() to figures/Frequency Study at 0.4V with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'nu_up', 'dIdV_up')
# (eva) saveMap() to figures/Frequency Study at 0.4V with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'nu_up', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Frequency Study at 0.4V with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'nu_up', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Frequency Study at 0.4V with Antenna.png
# (eva) z_lim = [None, None]
# ...

# %%
# Amplitude Study at 12.1 GHz with Antenna (2)
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 12.1 GHz with Antenna (2)'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.08, 1.08]
eva.z_lim = [0, .2]
eva.smoothing = True
eva.window_length = 40
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 12.1 GHz with Antenna (2)
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.08, 1.08]
# (eva) z_lim = [0, 0.2]
# (eva) smoothing = True
# (eva) window_length = 40
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 12.1 GHz with Antenna (2).png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 12.1 GHz with Antenna (2).png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 12.1 GHz with Antenna (2).png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# ...

# %%
# Amplitude Study at 12.1 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 12.1 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.smoothing = True
eva.window_length = 40
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 12.1 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) smoothing = True
# (eva) window_length = 40
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 12.1 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 12.1 GHz with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 12.1 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# ...

# %%
# Amplitude Study at 19.0 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 19.0 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .65]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.smoothing = True
eva.window_length = 40
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 19.0 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.65]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) smoothing = True
# (eva) window_length = 40
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 19.0 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 19.0 GHz with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 19.0 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# ...
