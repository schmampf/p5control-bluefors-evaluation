# %%
# initialize stuff
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
plt.ioff()

import sys
sys.path.append("/Users/oliver/Documents/p5control-bluefors-evaluation")
sys.path.append("/home/oliver/Documents/p5control-bluefors-evaluation")

from utilities.corporate_design_colors_v4 import cmap
from utilities.baseplotting import BasePlotting

import logging
from importlib import reload

logger = logging.getLogger(__name__)
reload(logging)
logging.basicConfig(level=logging.INFO, format='%(message)s')

# %% [markdown]
# ### Evaluation

# %%
# Amplitude Study at 7.8 GHz with Antenna (1m 4s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.base["title"]='Amplitude Study at 7.8 GHz with Antenna'
eva.base["sub_folder"] = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name  = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.8000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showFile()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.8000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.8000GHz_0.010V', 'vna_7.8000GHz_0.795V', 'vna_7.8000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [01:02<00:00,  2.56it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.7 GHz with Antenna (18.4 s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.base["title"]='Amplitude Study at 7.7 GHz with Antenna'
eva.base["sub_folder"] = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.7000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showFile()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.7000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.7000GHz_0.010V', 'vna_7.7000GHz_0.795V', 'vna_7.7000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [00:09<00:00, 16.59it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.9 GHz with Antenna (23.1 s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title='Amplitude Study at 7.9 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.9000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showFile()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 7.9 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.9000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.9000GHz_0.010V', 'vna_7.9000GHz_0.795V', 'vna_7.9000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [00:09<00:00, 16.91it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.8 GHz with Stripline (1m 10s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title='Amplitude Study at 7.8 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.8000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 7.8 GHz with Stripline
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.8000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.8000GHz_0.010V', 'vna_7.8000GHz_0.795V', 'vna_7.8000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [01:02<00:00,  2.57it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.7 GHz with Stripline (31s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 7.7 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.7000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.7000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.7000GHz_0.010V', 'vna_7.7000GHz_0.795V', 'vna_7.7000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 160/160 [00:09<00:00, 16.66it/s]
# (eva) saveData()

# %%
# Amplitude Study at 7.9 GHz with Stripline (31s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 7.9 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/"
eva.file_name  = "OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_7.9000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.addKey(key="no_irradiation", y_value=0.005)
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 7.9 GHz with Stripline
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 05 magnetic field + 7.8 GHz/
# (eva) file_name = OI-24d-10 24-09-05 amplitude study at 7.8GHz with stripline 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.7000GHz', 'vna_amplitudes_7.8000GHz', 'vna_amplitudes_7.9000GHz']
# (eva) setMeasurement('vna_amplitudes_7.9000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.9000GHz_0.010V', 'vna_7.9000GHz_0.795V', 'vna_7.9000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 161/161 [00:08<00:00, 18.59it/s]
# (eva) saveData()

# %%
# Frequency Study at 0.4V with Antenna (54.5s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Frequency Study at 0.4V with Antenna'
eva.sub_folder = 'frequency studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 11 frequency study at 0.4V/"
eva.file_name  = "OI-24d-10 24-09-11 frequency study 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_frequencies_0.400V')
eva.showKeys()
eva.setKeys([4, -10, 1e9, "no_irradiation"])
eva.setV(1.3e-3, voltage_bins=1300)
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Frequency Study at 0.4V with Antenna
# (eva) sub_folder = frequency studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 11 frequency study at 0.4V/
# (eva) file_name = OI-24d-10 24-09-11 frequency study 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_frequencies_0.400V']
# (eva) setMeasurement('vna_frequencies_0.400V')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_1.0000GHz_0.400V', 'vna_9.8000GHz_0.400V', 'vna_9.9000GHz_0.400V']
# (eva) setKeys([4, -10, 1000000000.0, 'no_irradiation'])
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) getMaps()
# 100%|██████████| 191/191 [00:42<00:00,  4.53it/s]
# (eva) saveData()

# %%
# Amplitude Study at 12.1 GHz with Antenna (2)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 12.1 GHz with Antenna (2)'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/"
eva.file_name  = "OI-24d-10 24-09-13 amplitude study at 3.5GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_12.1000GHz')
eva.showKeys()
eva.setKeys([15, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.addKey(key="no_irradiation", y_value=0.005)
eva.setV(1.3e-3, voltage_bins=1300)
eva.upsampling = 100
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 12.1 GHz with Antenna (2)
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/
# (eva) file_name = OI-24d-10 24-09-13 amplitude study at 3.5GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_12.1000GHz']
# (eva) setMeasurement('vna_amplitudes_12.1000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_12.1000GHz_0.010V', 'vna_12.1000GHz_0.995V', 'vna_12.1000GHz_1.000V']
# (eva) setKeys([15, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) upsampling = 100
# (eva) getMaps()
# 100%|██████████| 201/201 [01:47<00:00,  1.88it/s]
# (eva) saveData()

# %%
# Amplitude Study at 12.1 GHz with Antenna (1m 47s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 12.1 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/"
eva.file_name  = "OI-24d-10 24-09-13 amplitude study at 12.1GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_12.1000GHz')
eva.showKeys()
eva.setKeys([15, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.addKey(key="no_irradiation", y_value=0.005)
eva.setV(1.3e-3, voltage_bins=1300)
eva.upsampling = 100
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 12.1 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/
# (eva) file_name = OI-24d-10 24-09-13 amplitude study at 12.1GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_12.1000GHz']
# (eva) setMeasurement('vna_amplitudes_12.1000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_12.1000GHz_0.010V', 'vna_12.1000GHz_0.995V', 'vna_12.1000GHz_1.000V']
# (eva) setKeys([15, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) upsampling = 100
# (eva) getMaps()
# 100%|██████████| 201/201 [01:46<00:00,  1.89it/s]
# (eva) saveData()

# %%
# Amplitude Study at 19.0 GHz with Antenna (1m 47s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 19.0 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/"
eva.file_name  = "OI-24d-10 24-09-13 amplitude study at 19GHz with antenna 0.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_19.0000GHz')
eva.showKeys()
eva.setKeys([15, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.addKey(key="no_irradiation", y_value=0.005)
eva.setV(1.3e-3, voltage_bins=1300)
eva.upsampling = 100
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 19.0 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/
# (eva) file_name = OI-24d-10 24-09-13 amplitude study at 19GHz with antenna 0.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_19.0000GHz']
# (eva) setMeasurement('vna_amplitudes_19.0000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_19.0000GHz_0.010V', 'vna_19.0000GHz_0.995V', 'vna_19.0000GHz_1.000V']
# (eva) setKeys([15, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) upsampling = 100
# (eva) getMaps()
# 100%|██████████| 201/201 [01:42<00:00,  1.95it/s]
# (eva) saveData()

# %%
# Amplitude Study at 3.5 GHz with Antenna
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 3.5 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/"
eva.file_name  = "OI-24d-10 24-09-13 amplitude study at 3.5GHz with antenna 1.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_amplitudes_3.5000GHz')
eva.showKeys()
eva.setKeys([14, -1, 1, "no_irradiation"])
eva.addKey(key="no_irradiation", y_value=0)
eva.addKey(key="no_irradiation", y_value=0.005)
eva.setV(1.3e-3, voltage_bins=1300)
eva.upsampling = 100
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 3.5 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 13 amplitude study 3.5, 12.1, 19 GHz/
# (eva) file_name = OI-24d-10 24-09-13 amplitude study at 3.5GHz with antenna 1.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_3.5000GHz']
# (eva) setMeasurement('vna_amplitudes_3.5000GHz')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_3.5000GHz_0.010V', 'vna_3.5000GHz_0.995V', 'vna_3.5000GHz_1.000V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) upsampling = 100
# (eva) getMaps()
# 100%|██████████| 201/201 [01:45<00:00,  1.90it/s]
# (eva) saveData()

# %%
# Frequency Study at 0.4V with Stripline (54.5s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Frequency Study at 0.4V with Stripline'
eva.sub_folder = 'frequency studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 11 frequency study at 0.4V/"
eva.file_name  = "OI-24d-10 24-09-13 frequency study with stripline 1.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_frequencies_0.400V')
eva.showKeys()
eva.setKeys([4, -10, 1e9, "no_irradiation"])
eva.setV(1.3e-3, voltage_bins=1300)
eva.upsampling = 100
eva.getMaps()
eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Frequency Study at 0.4V with Stripline
# (eva) sub_folder = frequency studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 11 frequency study at 0.4V/
# (eva) file_name = OI-24d-10 24-09-13 frequency study with stripline 1.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_frequencies_0.400V']
# (eva) setMeasurement('vna_frequencies_0.400V')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_1.0000GHz_0.400V', 'vna_9.8000GHz_0.400V', 'vna_9.9000GHz_0.400V']
# (eva) setKeys([4, -10, 1000000000.0, 'no_irradiation'])
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) upsampling = 100
# (eva) getMaps()
# 100%|██████████| 191/191 [01:14<00:00,  2.55it/s]
# (eva) saveData()

# %%
# Irradiation Study at magnetic field with stripline
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 7.9 GHz & 20 mT with Stripline'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 17 irradiation study at magentic field/"
eva.file_name  = "OI-24d-10 24-09-17 irraddiation study with magnetic field and stripline.hdf5"
eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setV(1.3e-3, voltage_bins=1300)

eva.sub_folder = 'amplitude studies/with magnetic field/'
for f in ['7.9']:
    for m in ['20', '30']:
        eva.title = f'Amplitude Study at {f} GHz & {m} mT with Stripline'
        eva.setMeasurement(f'vna_amplitudes_7.9000GHz magnet_+{m}.00mT')
        eva.showKeys()
        eva.setKeys([14, -1, 1, "no_irradiation"])
        eva.addKey(key="no_irradiation", y_value=0)
        eva.addKey(key="no_irradiation", y_value=0.005)
        eva.getMaps()
        eva.saveData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 7.9 GHz & 20 mT with Stripline
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 17 irradiation study at magentic field/
# (eva) file_name = OI-24d-10 24-09-17 irraddiation study with magnetic field and stripline.hdf5
# (eva) showAmplifications()
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_7.9000GHz magnet_+20.00mT', 'vna_amplitudes_7.9000GHz magnet_+30.00mT']
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) sub_folder = amplitude studies/with magnetic field/
# (eva) title = Amplitude Study at 7.9 GHz & 20 mT with Stripline
# (eva) setMeasurement('vna_amplitudes_7.9000GHz magnet_+20.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.9000GHz_0.010V', 'vna_7.9000GHz_0.795V', 'vna_7.9000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 161/161 [00:30<00:00,  5.29it/s]
# (eva) saveData()
# (eva) title = Amplitude Study at 7.9 GHz & 30 mT with Stripline
# (eva) setMeasurement('vna_amplitudes_7.9000GHz magnet_+30.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.9000GHz_0.010V', 'vna_7.9000GHz_0.795V', 'vna_7.9000GHz_0.800V']
# (eva) setKeys([14, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 161/161 [00:31<00:00,  5.13it/s]
# (eva) saveData()

# %%
# Irradiation Study at magnetic field with Antenna
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'Amplitude Study at 7.9 GHz & 20 mT with Antenna'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 17 irradiation study at magentic field/"
eva.file_name  = "OI-24d-10 24-09-17 irraddiation study with magnetic field and Antenna 1.hdf5"
# eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setV(1.3e-3, voltage_bins=1300)

eva.sub_folder = 'amplitude studies/with magnetic field/'
for f in ['7.9', '12.1', '19.0', '3.5']:
    for m in ['20', '30']:
        eva.title = f'Amplitude Study at {f} GHz & {m} mT with Antenna'
        eva.setMeasurement(f'vna_amplitudes_{f}000GHz magnet_+{m}.00mT')
        eva.showKeys()
        eva.setKeys([-6, -1, 1, "no_irradiation"])
        eva.addKey(key="no_irradiation", y_value=0)
        eva.addKey(key="no_irradiation", y_value=0.005)
        eva.getMaps()
        eva.saveData()

eva.sub_folder = 'frequency studies/with magnetic field/'
for a in ['0.1', '0.4']:
    for m in ['20', '30']:
        eva.title = f'Frequency Study at {a} V & {m} mT with Antenna'
        eva.setMeasurement(f'vna_frequencies_{a}00V magnet_+{m}.00mT')
        eva.showKeys()
        eva.setKeys([4, -10, 1e9, "no_irradiation"])
        eva.getMaps()
        eva.saveData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = Amplitude Study at 7.9 GHz & 20 mT with Antenna
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 17 irradiation study at magentic field/
# (eva) file_name = OI-24d-10 24-09-17 irraddiation study with magnetic field and Antenna 1.hdf5
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_amplitudes_12.1000GHz magnet_+20.00mT', 'vna_amplitudes_12.1000GHz magnet_+30.00mT', 'vna_amplitudes_19.0000GHz magnet_+20.00mT', 'vna_amplitudes_19.0000GHz magnet_+30.00mT', 'vna_amplitudes_3.5000GHz magnet_+20.00mT', 'vna_amplitudes_3.5000GHz magnet_+30.00mT', 'vna_amplitudes_7.9000GHz magnet_+20.00mT', 'vna_amplitudes_7.9000GHz magnet_+30.00mT', 'vna_frequencies_0.100V magnet_+20.00mT', 'vna_frequencies_0.100V magnet_+30.00mT', 'vna_frequencies_0.400V magnet_+20.00mT', 'vna_frequencies_0.400V magnet_+30.00mT']
# (eva) setV(-0.0013, 0.0013, 1300)
# (eva) sub_folder = amplitude studies/with magnetic field/
# (eva) title = Amplitude Study at 7.9 GHz & 20 mT with Antenna
# (eva) setMeasurement('vna_amplitudes_7.9000GHz magnet_+20.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.9000GHz_0.010V', 'vna_7.9000GHz_0.795V', 'vna_7.9000GHz_0.800V']
# (eva) setKeys([-6, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 161/161 [00:30<00:00,  5.35it/s]
# (eva) saveData()
# (eva) title = Amplitude Study at 7.9 GHz & 30 mT with Antenna
# (eva) setMeasurement('vna_amplitudes_7.9000GHz magnet_+30.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.9000GHz_0.010V', 'vna_7.9000GHz_0.795V', 'vna_7.9000GHz_0.800V']
# (eva) setKeys([-6, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 161/161 [00:30<00:00,  5.24it/s]
# (eva) saveData()
# (eva) title = Amplitude Study at 12.1 GHz & 20 mT with Antenna
# (eva) setMeasurement('vna_amplitudes_12.1000GHz magnet_+20.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_12.1000GHz_0.010V', 'vna_12.1000GHz_0.695V', 'vna_12.1000GHz_0.700V']
# (eva) setKeys([-6, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 141/141 [00:27<00:00,  5.21it/s]
# (eva) saveData()
# (eva) title = Amplitude Study at 12.1 GHz & 30 mT with Antenna
# (eva) setMeasurement('vna_amplitudes_12.1000GHz magnet_+30.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_12.1000GHz_0.010V', 'vna_12.1000GHz_0.695V', 'vna_12.1000GHz_0.700V']
# (eva) setKeys([-6, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 141/141 [00:29<00:00,  4.79it/s]
# (eva) saveData()
# (eva) title = Amplitude Study at 19.0 GHz & 20 mT with Antenna
# (eva) setMeasurement('vna_amplitudes_19.0000GHz magnet_+20.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_19.0000GHz_0.010V', 'vna_19.0000GHz_0.695V', 'vna_19.0000GHz_0.700V']
# (eva) setKeys([-6, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 141/141 [00:34<00:00,  4.10it/s]
# (eva) saveData()
# (eva) title = Amplitude Study at 19.0 GHz & 30 mT with Antenna
# (eva) setMeasurement('vna_amplitudes_19.0000GHz magnet_+30.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_19.0000GHz_0.010V', 'vna_19.0000GHz_0.695V', 'vna_19.0000GHz_0.700V']
# (eva) setKeys([-6, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 141/141 [00:37<00:00,  3.74it/s]
# (eva) saveData()
# (eva) title = Amplitude Study at 3.5 GHz & 20 mT with Antenna
# (eva) setMeasurement('vna_amplitudes_3.5000GHz magnet_+20.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_3.5000GHz_0.010V', 'vna_3.5000GHz_0.995V', 'vna_3.5000GHz_1.000V']
# (eva) setKeys([-6, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 201/201 [00:51<00:00,  3.87it/s]
# (eva) saveData()
# (eva) title = Amplitude Study at 3.5 GHz & 30 mT with Antenna
# (eva) setMeasurement('vna_amplitudes_3.5000GHz magnet_+30.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_3.5000GHz_0.010V', 'vna_3.5000GHz_0.995V', 'vna_3.5000GHz_1.000V']
# (eva) setKeys([-6, -1, 1, 'no_irradiation'])
# (eva) addKey(no_irradiation, 0)
# (eva) addKey(no_irradiation, 0.005)
# (eva) getMaps()
# 100%|██████████| 201/201 [00:51<00:00,  3.89it/s]
# (eva) saveData()
# (eva) sub_folder = frequency studies/with magnetic field/
# (eva) title = Frequency Study at 0.1 V & 20 mT with Antenna
# (eva) setMeasurement('vna_frequencies_0.100V magnet_+20.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_1.0000GHz_0.100V', 'vna_9.8000GHz_0.100V', 'vna_9.9000GHz_0.100V']
# (eva) setKeys([4, -10, 1000000000.0, 'no_irradiation'])
# (eva) getMaps()
# 100%|██████████| 191/191 [00:48<00:00,  3.96it/s]
# (eva) saveData()
# (eva) title = Frequency Study at 0.1 V & 30 mT with Antenna
# (eva) setMeasurement('vna_frequencies_0.100V magnet_+30.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_1.0000GHz_0.100V', 'vna_9.8000GHz_0.100V', 'vna_9.9000GHz_0.100V']
# (eva) setKeys([4, -10, 1000000000.0, 'no_irradiation'])
# (eva) getMaps()
# 100%|██████████| 191/191 [00:48<00:00,  3.95it/s]
# (eva) saveData()
# (eva) title = Frequency Study at 0.4 V & 20 mT with Antenna
# (eva) setMeasurement('vna_frequencies_0.400V magnet_+20.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_1.0000GHz_0.400V', 'vna_9.8000GHz_0.400V', 'vna_9.9000GHz_0.400V']
# (eva) setKeys([4, -10, 1000000000.0, 'no_irradiation'])
# (eva) getMaps()
# 100%|██████████| 191/191 [00:48<00:00,  3.97it/s]
# (eva) saveData()
# (eva) title = Frequency Study at 0.4 V & 30 mT with Antenna
# (eva) setMeasurement('vna_frequencies_0.400V magnet_+30.00mT')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_1.0000GHz_0.400V', 'vna_9.8000GHz_0.400V', 'vna_9.9000GHz_0.400V']
# (eva) setKeys([4, -10, 1000000000.0, 'no_irradiation'])
# (eva) getMaps()
# 100%|██████████| 191/191 [00:47<00:00,  3.98it/s]
# (eva) saveData()

# %% [markdown]
# ### Plotting

# %%
# Plot Amplitude Study at 7.8 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.8 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.x2_lim = [0, .7]
eva.i_lim = [0, 5]
eva.values=[0.1, 0.3, 0.6, 0.75]

eva.showAll()
eva.saveAll()
eva.saveData()
# eva.showAllMaps()
# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.8 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) x2_lim = [0, 0.7]
# (eva) i_lim = [0, 5]
# (eva) values = [0.1, 0.3, 0.6, 0.75]
# (eva) showAll('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA_abs')
# (eva) saveIV() to figures/Amplitude Study at 7.8 GHz with Antenna.png
# (eva) saveData()

# %%
# Plot Amplitude Study at 7.7 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.7 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.x2_lim = [0, .7]
eva.i_lim = [0, 5]
eva.values = [0.1, 0.3, 0.6, 0.75]
eva.window_length = 40

eva.showAll()
eva.saveAll()
eva.saveData()
# eva.showAllMaps()
# eva.showFile()
# Out:
# 2024-11-13 15:42:23.998 Python[49592:10175265] +[IMKClient subclass]: chose IMKClient_Modern
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.7 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) x2_lim = [0, 0.7]
# (eva) i_lim = [0, 5]
# (eva) values = [0.1, 0.3, 0.6, 0.75]
# (eva) window_length = 40
# (eva) showAll('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA_abs')
# (eva) saveIV() to figures/Amplitude Study at 7.7 GHz with Antenna.png
# (eva) saveData()

# %%
# Plot Amplitude Study at 7.9 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.9 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.x2_lim = [0, .7]
eva.i_lim = [0, 5]
eva.values = [0.1, 0.3, 0.6, 0.75]
eva.window_length = 40

eva.showAll()
eva.saveAll()
eva.saveData()
# eva.showAllMaps()
# eva.showFile()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Plot Amplitude Study at 7.9 GHz with Antenna
# ----> 2 get_ipython().run_line_magic('matplotlib', 'qt')
#       3 from utilities.baseplotting import BasePlotting
#       4 eva = BasePlotting('eva')
#
# File ~/Documents/p5control-bluefors-evaluation/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Documents/p5control-bluefors-evaluation/.venv/lib/python3.12/site-packages/IPython/core/magics/pylab.py:103, in PylabMagics.matplotlib(self, line)
#      98     print(
#      99         "Available matplotlib backends: %s"
#     100         % _list_matplotlib_backends_and_gui_loops()
#     101     )
#     102 else:
# --> 103     gui, backend = self.shell.enable_matplotlib(args.gui)
#     104     self._show_matplotlib_backend(args.gui, backend)
#
# File ~/Documents/p5control-bluefors-evaluation/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3659, in InteractiveShell.enable_matplotlib(self, gui)
#    3637 """Enable interactive matplotlib and inline figure support.
#    3638
#    3639 This takes the following steps:
#    (...)
#    3655     display figures inline.
#    3656 """
#    3657 from .pylabtools import _matplotlib_manages_backends
# -> 3659 if not _matplotlib_manages_backends() and gui in (None, "auto"):
#    3660     # Early import of backend_inline required for its side effect of
#    3661     # calling _enable_matplotlib_integration()
#    3662     import matplotlib_inline.backend_inline
#    3664 from IPython.core import pylabtools as pt
#
# File ~/Documents/p5control-bluefors-evaluation/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:498, in _matplotlib_manages_backends()
#     496 if _matplotlib_manages_backends_value is None:
#     497     try:
# --> 498         from matplotlib.backends.registry import backend_registry
#     500         _matplotlib_manages_backends_value = hasattr(
#     501             backend_registry, "resolve_gui_or_backend"
#     502         )
#     503     except ImportError:
#
# File ~/Documents/p5control-bluefors-evaluation/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:159
#     155 from packaging.version import parse as parse_version
#     157 # cbook must import matplotlib only within function
#     158 # definitions, so it is safe to import from it here.
# --> 159 from . import _api, _version, cbook, _docstring, rcsetup
#     160 from matplotlib.cbook import sanitize_sequence
#     161 from matplotlib._api import MatplotlibDeprecationWarning
#
# File ~/Documents/p5control-bluefors-evaluation/.venv/lib/python3.12/site-packages/matplotlib/rcsetup.py:28
#      26 from matplotlib.backends import BackendFilter, backend_registry
#      27 from matplotlib.cbook import ls_mapper
# ---> 28 from matplotlib.colors import Colormap, is_color_like
#      29 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      30 from matplotlib._enums import JoinStyle, CapStyle
#
# File ~/Documents/p5control-bluefors-evaluation/.venv/lib/python3.12/site-packages/matplotlib/colors.py:52
#      49 from numbers import Real
#      50 import re
# ---> 52 from PIL import Image
#      53 from PIL.PngImagePlugin import PngInfo
#      55 import matplotlib as mpl
#
# File ~/Documents/p5control-bluefors-evaluation/.venv/lib/python3.12/site-packages/PIL/Image.py:100
#      91 MAX_IMAGE_PIXELS: int | None = int(1024 * 1024 * 1024 // 4 // 3)
#      94 try:
#      95     # If the _imaging C module is not present, Pillow will not load.
#      96     # Note that other modules should not refer to _imaging directly;
#      97     # import Image and use the Image.core variable instead.
#      98     # Also note that Image.core is not a publicly documented interface,
#      99     # and should be considered private and subject to change.
# --> 100     from . import _imaging as core
#     102     if __version__ != getattr(core, "PILLOW_VERSION", None):
#     103         msg = (
#     104             "The _imaging extension was built for another version of Pillow or PIL:\n"
#     105             f"Core version: {getattr(core, 'PILLOW_VERSION', None)}\n"
#     106             f"Pillow version: {__version__}"
#     107         )
#
# KeyboardInterrupt:

# %%
# Plot Amplitude Study at 7.8 GHz with Stripline
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.8 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.x2_lim = [0, .6]
eva.i_lim = [0, 5]
eva.values = [0.1, 0.5, 0.55, 0.6, 0.65, 0.7]
eva.window_length = 20

eva.showAll()
eva.saveAll()
eva.saveData()
# eva.showAllMaps()
# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.8 GHz with Stripline
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) x2_lim = [0, 0.6]
# (eva) i_lim = [0, 5]
# (eva) values = [0.1, 0.5, 0.55, 0.6, 0.65, 0.7]
# (eva) window_length = 20
# (eva) showAll('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA_abs')
# (eva) saveIV() to figures/Amplitude Study at 7.8 GHz with Stripline.png
# (eva) saveData()

# %%
# Plot Amplitude Study at 7.7 GHz with Stripline
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.base["title"] = 'Amplitude Study at 7.7 GHz with Stripline'
eva.base["sub_folder"] = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.7 GHz with Stripline.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.7 GHz with Stripline.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.7 GHz with Stripline.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.7 GHz with Stripline.png
# (eva) z_lim = [None, None]
# (eva) showIV('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA')
# (eva) saveIV() to figures/Amplitude Study at 7.7 GHz with Stripline.png

# %%
# Plot Amplitude Study at 7.9 GHz with Stripline
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.9 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-.9, .9]
eva.z_lim = [0, .2]
# eva.showAllMaps()

eva.smoothing = True
eva.window_length = 50
eva.z_lim = [None, None]
eva.values=[0, 0.3, 0.6, 0.75]
eva.showAll()
eva.saveAll()
eva.saveData()
# eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.9 GHz with Stripline
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-0.9, 0.9]
# (eva) z_lim = [0, 0.2]
# (eva) smoothing = True
# (eva) window_length = 50
# (eva) z_lim = [None, None]
# (eva) values = [0, 0.3, 0.6, 0.75]
# (eva) showAll('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA_abs')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 18
#      16 eva.z_lim = [None, None]
#      17 eva.values=[0, 0.3, 0.6, 0.75]
# ---> 18 eva.showAll()
#      19 eva.saveAll()
#      20 eva.saveData()
#
# File ~/Documents/p5control-bluefors-evaluation/utilities/baseplotting.py:175, in BasePlotting.showAll(self)
#     172 i_data = eval(ppk[self.plot["i_key"]][0])  # pylint: disable=eval-used
#     174 if self.plot["smoothing"]:
# --> 175     z_data = savgol_filter(
#     176         z_data,
#     177         window_length=self.plot["window_length"],
#     178         polyorder=self.plot["polyorder"],
#     179     )
#     180     i_data = savgol_filter(
#     181         i_data,
#     182         window_length=self.plot["window_length"],
#     183         polyorder=self.plot["polyorder"],
#     184     )
#     186 indices = self.getIndices(y_data=y_data)
#
# File ~/Documents/p5control-bluefors-evaluation/.venv/lib/python3.12/site-packages/scipy/signal/_savitzky_golay.py:345, in savgol_filter(x, window_length, polyorder, deriv, delta, axis, mode, cval)
#     343 if mode == "interp":
#     344     if window_length > x.shape[axis]:
# --> 345         raise ValueError("If mode is 'interp', window_length must be less "
#     346                          "than or equal to the size of x.")
#     348     # Do not pad. Instead, for the elements within `window_length // 2`
#     349     # of the ends of the sequence, use the polynomial that is fitted to
#     350     # the last `window_length` elements.
#     351     y = convolve1d(x, coeffs, axis=axis, mode="constant")
#
# ValueError: If mode is 'interp', window_length must be less than or equal to the size of x.

# %%
eva.reshowAll(1)
# Out:
# (eva) reshowIV()

# %%
# Plot Amplitude Study at 7.9 GHz with Stripline
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 7.9 GHz with Stripline'
eva.sub_folder = 'amplitude studies/'
eva.loadData()

eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.1, 1.1]
eva.z_key = "T_all_norm_up"
eva.smoothing = False
eva.showMapVector()
eva.saveFigure(figure=eva.show_map_vector["fig"], subtitle='Temperature MapVector')
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 7.9 GHz with Stripline
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_key = T_all_norm_up
# (eva) smoothing = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'T_all_norm_up', 'T_up_K')

# %%
# Plot Frequency Study at 0.4V with Stripline
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Frequency Study at 0.4V with Stripline'
eva.sub_folder = 'frequency studies/'
eva.loadData()
eva.y_key = "nu_up"
eva.x_lim = [-1.4, 1.4]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[3.3, 4, 7.7, 14.4])
eva.saveIV()
eva.z_key = "dIdV_up_asym"
eva.inverted = False
eva.fig_nr_show_map = 15
eva.contrast = .5
eva.showMap()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Frequency Study at 0.4V with Stripline
# (eva) sub_folder = frequency studies/
# (eva) loadData()
# (eva) y_key = nu_up
# (eva) x_lim = [-1.4, 1.4]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'nu_up', 'dIdV_up')
# (eva) saveMap() to figures/Frequency Study at 0.4V with Stripline.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'nu_up', 'dIdV_up')
# (eva) saveMap() to figures/Frequency Study at 0.4V with Stripline.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'nu_up', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Frequency Study at 0.4V with Stripline.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'nu_up', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Frequency Study at 0.4V with Stripline.png
# (eva) z_lim = [None, None]
# (eva) showIV('V_bias_up_mV', 'nu_up', 'dIdV_up', 'T_up_K', 'I_up_nA')
# (eva) saveIV() to figures/Frequency Study at 0.4V with Stripline.png
# (eva) z_key = dIdV_up_asym
# (eva) inverted = False
# (eva) fig_nr_show_map = 15
# (eva) contrast = 0.5
# (eva) showMap('V_bias_up_mV', 'nu_up', 'dIdV_up_asym')
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x13a5e6390> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x117c79aa0> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x117ccba10> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x15be96050> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x15be75ff0> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x13a5e6390> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x117c79aa0> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x117ccba10> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x15be96050> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x15be75ff0> contents scale of 2 - updating layer to match.

# %%
# Plot Frequency Study at 0.4V with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Frequency Study at 0.4V with Antenna'
eva.sub_folder = 'frequency studies/'
eva.loadData()
eva.y_key = "nu_up"


eva.x_lim = [-1.4, 1.4]
eva.z_lim = [0, .2]
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[3.3, 4, 7.7, 14.4])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Frequency Study at 0.4V with Antenna
# (eva) sub_folder = frequency studies/
# (eva) loadData()
# (eva) y_key = nu_up
# (eva) x_lim = [-1.4, 1.4]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'nu_up', 'dIdV_up')
# (eva) saveMap() to figures/Frequency Study at 0.4V with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'nu_up', 'dIdV_up')
# (eva) saveMap() to figures/Frequency Study at 0.4V with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'nu_up', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Frequency Study at 0.4V with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'nu_up', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Frequency Study at 0.4V with Antenna.png
# (eva) z_lim = [None, None]
# (eva) showIV('V_bias_up_mV', 'nu_up', 'dIdV_up', 'T_up_K', 'I_up_nA')
# (eva) saveIV() to figures/Frequency Study at 0.4V with Antenna.png

# %%
# Amplitude Study at 12.1 GHz with Antenna (2)
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 12.1 GHz with Antenna (2)'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .8]
eva.x_lim = [-1.08, 1.08]
eva.z_lim = [0, .2]
eva.smoothing = True
eva.window_length = 40
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 12.1 GHz with Antenna (2)
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.8]
# (eva) x_lim = [-1.08, 1.08]
# (eva) z_lim = [0, 0.2]
# (eva) smoothing = True
# (eva) window_length = 40
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 12.1 GHz with Antenna (2).png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 12.1 GHz with Antenna (2).png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 12.1 GHz with Antenna (2).png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 12.1 GHz with Antenna (2).png
# (eva) z_lim = [None, None]
# (eva) showIV('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA')
# (eva) saveIV() to figures/Amplitude Study at 12.1 GHz with Antenna (2).png

# %%
# Amplitude Study at 12.1 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 12.1 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, 1]
eva.x_lim = [-1.5, 1.5]
eva.z_lim = [0, .2]
eva.n_lim = [0, .25]
eva.smoothing = True
eva.window_length = 40
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 12.1 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 1]
# (eva) x_lim = [-1.5, 1.5]
# (eva) z_lim = [0, 0.2]
# (eva) n_lim = [0, 0.25]
# (eva) smoothing = True
# (eva) window_length = 40
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 12.1 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 12.1 GHz with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 12.1 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 12.1 GHz with Antenna.png
# (eva) z_lim = [None, None]
# (eva) showIV('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA')
# (eva) saveIV() to figures/Amplitude Study at 12.1 GHz with Antenna.png

# %%
# Amplitude Study at 19.0 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 19.0 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, .65]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.smoothing = True
eva.window_length = 40
eva.showAllMaps()
eva.z_lim = [None, None]
eva.showIV(values=[0, 0.3, 0.6, 0.75])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 19.0 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 0.65]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) smoothing = True
# (eva) window_length = 40
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 19.0 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 19.0 GHz with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 19.0 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 19.0 GHz with Antenna.png
# (eva) z_lim = [None, None]
# (eva) showIV('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA')
# (eva) saveIV() to figures/Amplitude Study at 19.0 GHz with Antenna.png

# %%
# Amplitude Study at 3.5 GHz with Antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
eva.title = 'Amplitude Study at 3.5 GHz with Antenna'
eva.sub_folder = 'amplitude studies/'
eva.loadData()
eva.y_key = "V_ac_up_V"
eva.y_lim = [-0, 1]
eva.x_lim = [-1.1, 1.1]
eva.z_lim = [0, .2]
eva.smoothing = True
eva.window_length = 40
eva.showAllMaps()
eva.z_lim = [0, None]
eva.window_length = 20
eva.showIV(values=[0, 0.3, 0.6, 0.75, .85, .95, 1])
eva.saveIV()

# eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) title = Amplitude Study at 3.5 GHz with Antenna
# (eva) sub_folder = amplitude studies/
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, 1]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) smoothing = True
# (eva) window_length = 40
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 3.5 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 3.5 GHz with Antenna.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 3.5 GHz with Antenna.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 3.5 GHz with Antenna.png
# (eva) z_lim = [0, None]
# (eva) window_length = 20
# (eva) showIV('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA')
# (eva) saveIV() to figures/Amplitude Study at 3.5 GHz with Antenna.png

# %%
# Irradiation Study at magnetic field with antenna
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')

eva.sub_folder = 'amplitude studies/with magnetic field/'
for f in ['7.9']:
    for m in ['20', '30']:
        eva.title = f'Amplitude Study at {f} GHz & {m} mT with Stripline'

        eva.loadData()
        eva.y_key = "V_ac_up_V"
        eva.y_lim = [-0, None]
        eva.x_lim = [-1.1, 1.1]
        eva.z_lim = [0, .2]
        eva.showAllMaps()
        eva.z_lim = [0, None]
        eva.window_length = 20
        eva.showIV(values=[0, 0.3, 0.6, 0.75, .85, .95, 1])
        eva.saveIV()
        # eva.showFile()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) sub_folder = amplitude studies/with magnetic field/
# (eva) title = Amplitude Study at 7.9 GHz & 20 mT with Stripline
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, None]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.9 GHz & 20 mT with Stripline.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.9 GHz & 20 mT with Stripline.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.9 GHz & 20 mT with Stripline.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.9 GHz & 20 mT with Stripline.png
# (eva) z_lim = [0, None]
# (eva) window_length = 20
# (eva) showIV('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA')
# (eva) saveIV() to figures/Amplitude Study at 7.9 GHz & 20 mT with Stripline.png
# (eva) title = Amplitude Study at 7.9 GHz & 30 mT with Stripline
# (eva) loadData()
# (eva) y_key = V_ac_up_V
# (eva) y_lim = [0, None]
# (eva) x_lim = [-1.1, 1.1]
# (eva) z_lim = [0, 0.2]
# (eva) inverted = False
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.9 GHz & 30 mT with Stripline.png
# (eva) inverted = True
# (eva) showMap('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up')
# (eva) saveMap() to figures/Amplitude Study at 7.9 GHz & 30 mT with Stripline.png
# (eva) inverted = False
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.9 GHz & 30 mT with Stripline.png
# (eva) inverted = True
# (eva) showMapVector('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K')
# (eva) saveMapVector() to figures/Amplitude Study at 7.9 GHz & 30 mT with Stripline.png
# (eva) z_lim = [0, None]
# (eva) window_length = 20
# (eva) showIV('V_bias_up_mV', 'V_ac_up_V', 'dIdV_up', 'T_up_K', 'I_up_nA')
# (eva) saveIV() to figures/Amplitude Study at 7.9 GHz & 30 mT with Stripline.png

# %%
# Irradiation Study at magnetic field with stripline at 30 mT
# %matplotlib qt
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')

eva.sub_folder = 'amplitude studies/with magnetic field/'
for f in ['7.9', '12.1', '19.0', '3.5']:
    for m in ['20', '30']:
        eva.title = f'Amplitude Study at {f} GHz & {m} mT with Antenna'

        eva.loadData()
        eva.y_key = "V_ac_up_V"
        eva.y_lim = [-0, None]
        eva.x_lim = [-1.1, 1.1]
        eva.z_lim = [0, .2]
        eva.showAllMaps()
        eva.z_lim = [0, None]
        eva.window_length = 20
        eva.showIV(values=[0, 0.3, 0.6, 0.75, .85, .95, 1])
        eva.saveIV()
        # eva.showFile()
        
eva.sub_folder = 'frequency studies/with magnetic field/'
for a in ['0.1', '0.4']:
    for m in ['20', '30']:
        eva.title = f'Frequency Study at {a} V & {m} mT with Antenna'
        eva.loadData()
        eva.y_key = "nu_up"
        eva.x_lim = [-1.1, 1.1]
        eva.z_lim = [0, .2]
        eva.y_lim = [1, 20]
        eva.showAllMaps()
        eva.z_lim = [None, None]
        eva.showIV(values=[3.5, 7.9, 12.1, 19.0])
        eva.saveIV()

# %%
################################################

# %%
# Reshow all
# %matplotlib qt
plt.close('all')
from utilities.baseplotting import BasePlotting
eva = BasePlotting('eva')
plt.ioff()

eva.sub_folder = 'magnetic field studies/'
eva.reshowAll(  0, 'Magnetic Field Study (high res)')

eva.sub_folder = 'amplitude studies/'
eva.reshowAll(  1, 'Amplitude Study at 7.8 GHz with Antenna')
eva.reshowAll(  2, 'Amplitude Study at 7.7 GHz with Antenna')
eva.reshowAll(  3, 'Amplitude Study at 7.9 GHz with Antenna')
eva.reshowAll(  4, 'Amplitude Study at 7.7 GHz with Antenna')
eva.reshowAll(  5, 'Amplitude Study at 7.7 GHz with Antenna')
plt.close()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) ... BasePlotting initialized.
# (eva) sub_folder = magnetic field studies/
# (eva) reshowIV()
# (eva) title = Magnetic Field Study (high res)
# (eva) loadData()
# (eva) sub_folder = amplitude studies/
# (eva) reshowIV()
# (eva) title = Amplitude Study at 7.8 GHz with Antenna
# (eva) loadData()
# (eva) reshowIV()
# (eva) title = Amplitude Study at 7.7 GHz with Antenna
# (eva) loadData()
# (eva) reshowIV()
# (eva) title = Amplitude Study at 7.9 GHz with Antenna
# (eva) loadData()
# (eva) reshowIV()
# (eva) title = Amplitude Study at 7.7 GHz with Antenna
# (eva) loadData()
# (eva) reshowIV()
# (eva) title = Amplitude Study at 7.7 GHz with Antenna
# (eva) loadData()

# %%
plt.close('all')

# %%
# Patricks Daten nach Asymmetrie durchsuchen
# IV absolut
# elektronische Temperatur - BCS fit, mit dynes, Laura Doktorarbeit, Marcel?
# kombined plot dIdV map and curves

# %%
# irradiation study with magnetic field

# %%
# Frequency Study at 0.4V with Stripline (54.5s)
# %matplotlib inline
from utilities.baseevaluation import BaseEvaluation
eva = BaseEvaluation('eva')
eva.title = 'None'
eva.sub_folder = 'frequency studies/'
eva.file_folder = "24 07 OI-24d-10/unbroken/24 09 17 irradiation study at magentic field/"
eva.file_name  = "OI-24d-10 24-09-17 irraddiation study 7.6-8.1 GHz and 0-0.8V with stripline.hdf5"
# eva.showAmplifications()
eva.setAmplifications(1000, 10000)
eva.showMeasurements()
eva.setMeasurement('vna_irradiations')
eva.showKeys()
# eva.setKeys([4, -10, 1e9, "no_irradiation"])
# eva.setV(1.3e-3, voltage_bins=1300)
# eva.upsampling = 100
# eva.getMaps()
# eva.saveData()
# eva.showData()
# Out:
# (eva) ... BaseClass initialized.
# (eva) ... BaseEvaluation initialized.
# (eva) title = None
# (eva) sub_folder = frequency studies/
# (eva) file_folder = 24 07 OI-24d-10/unbroken/24 09 17 irradiation study at magentic field/
# (eva) file_name = OI-24d-10 24-09-17 irraddiation study 7.6-8.1 GHz and 0-0.8V with stripline.hdf5
# (eva) setAmplifications(1000, 10000)
# (eva) showMeasurements()
# (eva) ['vna_irradiations']
# (eva) setMeasurement('vna_irradiations')
# (eva) showKeys()
# (eva) ['no_irradiation', 'vna_7.6000GHz_0.010V', 'vna_8.1000GHz_0.790V', 'vna_8.1000GHz_0.800V']
